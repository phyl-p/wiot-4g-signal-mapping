# %% [markdown]
# ## 4G Signal Strength Mapping in UVA Engineering School
# ### WIoT Final Project Group 5
#
# **Project Motivation**:
# Long range signal transmission can have blind spots well within their proposed range–as we have seen for LoRa and BLE, where the theoretical range is a lot shorter or is significantly reduced due to the objects in the environment. LoRa has a proposed range of 3 miles in urban areas, but as shown in the results of the measurements in this class, it can have certain blind spots well within the 3 mile range, especially in underground settings such as basements. 4G/5G are important means of communication on Grounds, and they are relied upon for real time communication in case WiFi fails. Yet, it is sometimes reported that the 4G/5G coverage on Grounds is not ideal, especially in terms of underground environments. The Engineering School has a lot of buildings where the basements are environments where important experiments take place. Having robust and redundant communication is important for the safety of both the faculty, staff, students, and their work. Hence, we propose to measure the 4G/5G coverage in the E-School and around grounds. We will use various internet speed measurement apps on our phones to collect the data at specific geographic locations, indoors and outdoors. Using this data we can then create heatmaps for both indoor and outdoor settings, exploring the differences and enlightening the community to areas of low coverage.
#
# **This python notebook is step 3 of our project where we map the collected signal strength data**
#
# Data Mapping Plan:
# 1. map data by type of sinal strenght (upload, download, rssi), floors and their coordinates.
# 2. Collect stats, such as mean, std, and range by floor, building and graph bar chart

# %% [markdown]
# Library Setup and Data Import

# %%
import pandas as pd
import numpy as np
import plotly.express as px
print('Note: all ploly graphs are interactive, to gain further (quantitative, other data) for a data point, hover your cursr above a dot')
# Out:
# Note: all ploly graphs are interactive, to gain further (quantitative, other data) for a data point, hover your cursr above a dot

# %%
indoors = pd.read_csv("WIoT Final Project 4G_5G Data - Indoor.csv")
outdoors = pd.read_csv("WIoT Final Project 4G_5G Data - Outdoor.csv")

# %% [markdown]
# Data Exploration and Processing

# %%
print(outdoors.columns)
print(outdoors.info())
# Out:
# Index(['Location ID', 'Description', 'Lat', 'Long', '4G RSSI signal',
#        '4G download rate', '4G upload rate'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Location ID       22 non-null     object
#  1   Description       22 non-null     object
#  2   Lat               22 non-null     float64
#  3   Long              22 non-null     float64
#  4   4G RSSI signal    22 non-null     int64
#  5   4G download rate  22 non-null     float64
#  6   4G upload rate    22 non-null     float64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 1.3+ KB
# None

# %%
print(indoors.columns)
print(indoors.info())
# Out:
# Index(['Location ID', 'Description', 'Floor', 'Lat', 'Long', '4G RSSI signal',
#        '4G download rate', '4G upload rate'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79 entries, 0 to 78
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Location ID       79 non-null     object
#  1   Description       79 non-null     object
#  2   Floor             79 non-null     object
#  3   Lat               79 non-null     float64
#  4   Long              79 non-null     float64
#  5   4G RSSI signal    79 non-null     int64
#  6   4G download rate  79 non-null     float64
#  7   4G upload rate    79 non-null     float64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 5.1+ KB
# None

# %% [markdown]
# # Data Visualizations

# %%
fig = px.scatter_mapbox(indoors, 
                        lat='Lat', lon='Long', 
                        mapbox_style="stamen-terrain", zoom=16.2,
                        color='Floor',
                        size = '4G download rate',
                        color_continuous_scale=px.colors.sequential.Cividis_r,
                        opacity = 0.3,
                        hover_name='Description', 
                        hover_data=['Location ID','4G RSSI signal', '4G upload rate'],
                        title = '4G download rate, By Floors',
 )
fig.update_layout(mapbox_style = 'carto-positron')
fig.show()
# Out:
# <div>                            <div id="ef750c14-5513-407a-8b5c-15de9fd8ac72" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ef750c14-5513-407a-8b5c-15de9fd8ac72")) {                    Plotly.newPlot(                        "ef750c14-5513-407a-8b5c-15de9fd8ac72",                        [{"customdata":[["Rice Hall",-91,33.5],["Rice Hall",-89,22.8],["Rice Hall",-71,20.0]],"hovertemplate":"<b>%{hovertext}</b><br><br>Floor=5<br>4G download rate=%{marker.size}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G RSSI signal=%{customdata[1]}<br>4G upload rate=%{customdata[2]}<extra></extra>","hovertext":["Rice Hall West","Rice Hall Central","Rice Hall East"],"lat":[38.031395,38.031738,38.03175],"legendgroup":"5","lon":[-78.510704,-78.51107,-78.511063],"marker":{"color":"#636efa","opacity":0.3,"size":[73.4,79.5,56.6],"sizemode":"area","sizeref":0.20074999999999998},"mode":"markers","name":"5","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["Rice Hall",-81,19.6],["Rice Hall",-77,19.4],["Rice Hall",-84,15.7]],"hovertemplate":"<b>%{hovertext}</b><br><br>Floor=4<br>4G download rate=%{marker.size}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G RSSI signal=%{customdata[1]}<br>4G upload rate=%{customdata[2]}<extra></extra>","hovertext":["Rice Hall West","Rice Hall Central","Rice Hall East"],"lat":[38.031395,38.031738,38.03175],"legendgroup":"4","lon":[-78.510704,-78.51107,-78.511063],"marker":{"color":"#EF553B","opacity":0.3,"size":[69.3,55.3,41.6],"sizemode":"area","sizeref":0.20074999999999998},"mode":"markers","name":"4","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["Rice Hall",-84,6.9],["Rice Hall",-83,11.7],["Rice Hall",-85,26.6],["Wilsdorf Hall",-102,4.6],["Wilsdorf Hall",-98,4.7],["Jesser Hall",-82,4.6],["Thornton Hall",-85,4.7],["Thornton Hall",-87,4.7]],"hovertemplate":"<b>%{hovertext}</b><br><br>Floor=3<br>4G download rate=%{marker.size}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G RSSI signal=%{customdata[1]}<br>4G upload rate=%{customdata[2]}<extra></extra>","hovertext":["Rice Hall West","Rice Hall Central","Rice Hall East","Wilsdorf North","Wilsdorf South","Jesser Hall","E-Wing","E-Wing"],"lat":[38.031395,38.031738,38.03175,38.03392,38.033081,38.033295,38.032623,38.032265],"legendgroup":"3","lon":[-78.510704,-78.51107,-78.511063,-78.511032,-78.511452,-78.510803,-78.50956,-78.509834],"marker":{"color":"#00cc96","opacity":0.3,"size":[52.2,58.9,80.3,0.5,1.7,1.9,2.1,4.3],"sizemode":"area","sizeref":0.20074999999999998},"mode":"markers","name":"3","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["Rice Hall",-90,14.3],["Rice Hall",-95,30.8],["Rice Hall",-102,23.5],["Olsson Hall",-96,4.6],["Olsson Hall",-100,4.7],["Olsson Hall",-98,4.7],["Wilsdorf Hall",-100,4.7],["Wilsdorf Hall",-93,4.6],["Jesser Hall",-85,5.6],["Thornton Hall",-89,4.7],["Thornton Hall",-92,4.7],["Thornton Hall",-88,4.7],["Thornton Hall",-91,4.7],["Thornton Hall",-85,4.6],["Thornton Hall",-80,0.0],["Thornton Hall",-85,4.7],["Thornton Hall",-78,4.7],["Thornton Hall",-100,4.6],["Thornton Hall",-96,0.0],["Thornton Hall",-87,5.8],["Mechanical Engineering",-86,4.6],["Mechanical Engineering",-82,4.7],["Mechanical Engineering",-79,7.0]],"hovertemplate":"<b>%{hovertext}</b><br><br>Floor=2<br>4G download rate=%{marker.size}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G RSSI signal=%{customdata[1]}<br>4G upload rate=%{customdata[2]}<extra></extra>","hovertext":["Rice Hall West","Rice Hall Central","Rice Hall East","Olsson Hall West","Olsson Hall North","Olsson Hall East","Wilsdorf North","Wilsdorf South","Jesser Hall","A-Wing West","A-Wing Central","A-Wing East","B-Wing","B-Wi ...

# %%
fig = px.scatter_mapbox(indoors, 
                        lat='Lat', lon='Long', 
                        mapbox_style="stamen-terrain", zoom=16.2,
                        color='Floor',
                        size = '4G upload rate',
                        color_continuous_scale=px.colors.sequential.Cividis_r,
                        opacity = 0.3,
                        hover_name='Description', 
                        hover_data=['Location ID','4G RSSI signal', '4G upload rate'],
                        title = '4G upload rate, By Floors',
 )
fig.update_layout(mapbox_style = 'carto-positron')
fig.show()
# Out:
# <div>                            <div id="dd606fe6-4e9c-481f-b492-04f278f3dd16" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dd606fe6-4e9c-481f-b492-04f278f3dd16")) {                    Plotly.newPlot(                        "dd606fe6-4e9c-481f-b492-04f278f3dd16",                        [{"customdata":[["Rice Hall",-91,33.5],["Rice Hall",-89,22.8],["Rice Hall",-71,20.0]],"hovertemplate":"<b>%{hovertext}</b><br><br>Floor=5<br>4G upload rate=%{customdata[2]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G RSSI signal=%{customdata[1]}<extra></extra>","hovertext":["Rice Hall West","Rice Hall Central","Rice Hall East"],"lat":[38.031395,38.031738,38.03175],"legendgroup":"5","lon":[-78.510704,-78.51107,-78.511063],"marker":{"color":"#636efa","opacity":0.3,"size":[33.5,22.8,20.0],"sizemode":"area","sizeref":0.08375},"mode":"markers","name":"5","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["Rice Hall",-81,19.6],["Rice Hall",-77,19.4],["Rice Hall",-84,15.7]],"hovertemplate":"<b>%{hovertext}</b><br><br>Floor=4<br>4G upload rate=%{customdata[2]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G RSSI signal=%{customdata[1]}<extra></extra>","hovertext":["Rice Hall West","Rice Hall Central","Rice Hall East"],"lat":[38.031395,38.031738,38.03175],"legendgroup":"4","lon":[-78.510704,-78.51107,-78.511063],"marker":{"color":"#EF553B","opacity":0.3,"size":[19.6,19.4,15.7],"sizemode":"area","sizeref":0.08375},"mode":"markers","name":"4","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["Rice Hall",-84,6.9],["Rice Hall",-83,11.7],["Rice Hall",-85,26.6],["Wilsdorf Hall",-102,4.6],["Wilsdorf Hall",-98,4.7],["Jesser Hall",-82,4.6],["Thornton Hall",-85,4.7],["Thornton Hall",-87,4.7]],"hovertemplate":"<b>%{hovertext}</b><br><br>Floor=3<br>4G upload rate=%{customdata[2]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G RSSI signal=%{customdata[1]}<extra></extra>","hovertext":["Rice Hall West","Rice Hall Central","Rice Hall East","Wilsdorf North","Wilsdorf South","Jesser Hall","E-Wing","E-Wing"],"lat":[38.031395,38.031738,38.03175,38.03392,38.033081,38.033295,38.032623,38.032265],"legendgroup":"3","lon":[-78.510704,-78.51107,-78.511063,-78.511032,-78.511452,-78.510803,-78.50956,-78.509834],"marker":{"color":"#00cc96","opacity":0.3,"size":[6.9,11.7,26.6,4.6,4.7,4.6,4.7,4.7],"sizemode":"area","sizeref":0.08375},"mode":"markers","name":"3","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["Rice Hall",-90,14.3],["Rice Hall",-95,30.8],["Rice Hall",-102,23.5],["Olsson Hall",-96,4.6],["Olsson Hall",-100,4.7],["Olsson Hall",-98,4.7],["Wilsdorf Hall",-100,4.7],["Wilsdorf Hall",-93,4.6],["Jesser Hall",-85,5.6],["Thornton Hall",-89,4.7],["Thornton Hall",-92,4.7],["Thornton Hall",-88,4.7],["Thornton Hall",-91,4.7],["Thornton Hall",-85,4.6],["Thornton Hall",-80,0.0],["Thornton Hall",-85,4.7],["Thornton Hall",-78,4.7],["Thornton Hall",-100,4.6],["Thornton Hall",-96,0.0],["Thornton Hall",-87,5.8],["Mechanical Engineering",-86,4.6],["Mechanical Engineering",-82,4.7],["Mechanical Engineering",-79,7.0]],"hovertemplate":"<b>%{hovertext}</b><br><br>Floor=2<br>4G upload rate=%{customdata[2]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G RSSI signal=%{customdata[1]}<extra></extra>","hovertext":["Rice Hall West","Rice Hall Central","Rice Hall East","Olsson Hall West","Olsson Hall North","Olsson Hall East","Wilsdorf North","Wilsdorf South","Jesser Hall","A-Wing West","A-Wing Central","A-Wing East","B-Wing","B-Wing","C-Wing","C-Wing","D-Wing","D-Wing","E-Wing","E-Wing","Mech North","Mech Central","Mech South"],"lat":[38.031395,38.031738,38.03175,38.031818,38.032074,38.03199,38.03392,38. ...

# %% [markdown]
# ## RSSI Signal Strength by Floor

# %%
rssi_max = indoors['4G RSSI signal'].max()
rssi_min = indoors['4G RSSI signal'].min()
range_rssi = [rssi_min, rssi_max] 
print("MAX RSSI: ", rssi_max)
print("MAX RSSI: ", rssi_min)
# Out:
# MAX RSSI:  -71
# MAX RSSI:  -200

# %%
fig = px.histogram(indoors, '4G RSSI signal', 
                   color = 'Floor', barmode='group',  
                   title='Histogram of 4G RSSI signal, by Revenue',
                  )
#labels={'count':'number of sessions',
#                      'ProductRelated_Duration':'Time Spent Viewing Product-related Webpage',
#                      'Revenue':'Successful Sale',
#                      1:'Success',
#                      0:'No success'
#                     }
fig.show()
# Out:
# <div>                            <div id="00de88b8-9497-4da7-8955-8d17e0579f1e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("00de88b8-9497-4da7-8955-8d17e0579f1e")) {                    Plotly.newPlot(                        "00de88b8-9497-4da7-8955-8d17e0579f1e",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Floor=5<br>4G RSSI signal=%{x}<br>count=%{y}<extra></extra>","legendgroup":"5","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"5","offsetgroup":"5","orientation":"v","showlegend":true,"x":[-91,-89,-71],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Floor=4<br>4G RSSI signal=%{x}<br>count=%{y}<extra></extra>","legendgroup":"4","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"4","offsetgroup":"4","orientation":"v","showlegend":true,"x":[-81,-77,-84],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Floor=3<br>4G RSSI signal=%{x}<br>count=%{y}<extra></extra>","legendgroup":"3","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"3","offsetgroup":"3","orientation":"v","showlegend":true,"x":[-84,-83,-85,-102,-98,-82,-85,-87],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Floor=2<br>4G RSSI signal=%{x}<br>count=%{y}<extra></extra>","legendgroup":"2","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"2","offsetgroup":"2","orientation":"v","showlegend":true,"x":[-90,-95,-102,-96,-100,-98,-100,-93,-85,-89,-92,-88,-91,-85,-80,-85,-78,-100,-96,-87,-86,-82,-79],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Floor=1<br>4G RSSI signal=%{x}<br>count=%{y}<extra></extra>","legendgroup":"1","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"1","offsetgroup":"1","orientation":"v","showlegend":true,"x":[-92,-95,-85,-113,-115,-109,-94,-92,-102,-98,-93,-97,-90,-87,-93,-72,-89,-111,-99,-93,-90,-88,-110],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Floor=0<br>4G RSSI signal=%{x}<br>count=%{y}<extra></extra>","legendgroup":"0","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"0","offsetgroup":"0","orientation":"v","showlegend":true,"x":[-80,-94,-93,-117,-122,-108,-110,-107,-103,-102,-84,-101,-99,-96,-101],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Floor=A<br>4G RSSI signal=%{x}<br>count=%{y}<extra></extra>","legendgroup":"A","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"A","offsetgroup":"A","orientation":"v","showlegend":true,"x":[-200,-200],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Floor=B<br>4G RSSI signal=%{x}<br>count=%{y}<extra></extra>","legendgroup":"B","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"B","offsetgroup":"B","orientation":"v","showlegend":true,"x":[-200,-200],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"# ...

# %% [markdown]
# #### *Basement floors* RSSI Signal

# %%
basement_data = indoors[(indoors['Floor'] == '0')| (indoors['Floor'] == 'A' )| (indoors['Floor'] == 'B')]
fig = px.scatter_mapbox(basement_data, 
                        lat='Lat', lon='Long', 
                        mapbox_style="stamen-terrain", zoom=16.2,
                        color='4G RSSI signal',
                        color_continuous_scale=px.colors.sequential.Cividis_r,
                        range_color = range_rssi,
                        opacity = 1,
                        hover_name='Description', 
                        hover_data=['Location ID','4G RSSI signal'],
                        title = 'RSSI Signal Strength, Basement Floors',
 )
fig.update_layout(mapbox_style = 'carto-positron')
fig.show()
# Out:
# <div>                            <div id="e1ea05a3-cc9f-4f22-b67d-45166b4ed254" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e1ea05a3-cc9f-4f22-b67d-45166b4ed254")) {                    Plotly.newPlot(                        "e1ea05a3-cc9f-4f22-b67d-45166b4ed254",                        [{"customdata":[["Rice Hall",-80],["Rice Hall",-94],["Rice Hall",-93],["Olsson Hall",-117],["Olsson Hall",-122],["Olsson Hall",-108],["Wilsdorf Hall",-200],["Wilsdorf Hall",-200],["Wilsdorf Hall",-200],["Wilsdorf Hall",-200],["Thornton Hall",-110],["Thornton Hall",-107],["Thornton Hall",-103],["Thornton Hall",-102],["Thornton Hall",-84],["Mechanical Engineering",-101],["Mechanical Engineering",-99],["Mechanical Engineering",-96],["Small Hall",-101]],"hovertemplate":"<b>%{hovertext}</b><br><br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G RSSI signal=%{marker.color}<extra></extra>","hovertext":["Rice Hall West","Rice Hall Central","Rice Hall East","Olsson Hall West","Olsson Hall North","Olsson Hall East","Wilsdorf North","Wilsdorf North","Wilsdorf South","Wilsdorf South","A-Wing West","A-Wing Central","A-Wing East","C-Wing","D-Wing","Mech North","Mech Central","Mech South","Small Hall"],"lat":[38.031395,38.031738,38.03175,38.031818,38.032074,38.03199,38.03392,38.03392,38.033081,38.033081,38.033329,38.033348,38.03307,38.032612,38.032509,38.032543,38.032852,38.032898,38.032078],"legendgroup":"","lon":[-78.510704,-78.51107,-78.511063,-78.510201,-78.510175,-78.510818,-78.511032,-78.511032,-78.511452,-78.511452,-78.509903,-78.509521,-78.509209,-78.509552,-78.510414,-78.511208,-78.511047,-78.511139,-78.510933],"marker":{"color":[-80,-94,-93,-117,-122,-108,-200,-200,-200,-200,-110,-107,-103,-102,-84,-101,-99,-96,-101],"coloraxis":"coloraxis","opacity":1},"mode":"markers","name":"","showlegend":false,"subplot":"mapbox","type":"scattermapbox"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333, ...

# %% [markdown]
# #### *First Floor* RSSI Signal

# %%
#GRAPH Basement floors RSSI Signal
first_floor = indoors[indoors['Floor'] == '1']
fig = px.scatter_mapbox(first_floor, 
                        lat='Lat', lon='Long', 
                        mapbox_style="stamen-terrain", zoom=16.2,
                        color='4G RSSI signal',
                        color_continuous_scale=px.colors.sequential.Cividis_r,
                        range_color = range_rssi,
                        opacity = 1,
                        hover_name='Description', 
                        hover_data=['Location ID','4G RSSI signal'],
                        title = 'RSSI Signal Strength, First Floors'
 )
fig.update_layout(mapbox_style = 'carto-positron')
fig.show()
# Out:
# <div>                            <div id="9cef73c0-923c-4e1b-8275-33d9e5602390" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9cef73c0-923c-4e1b-8275-33d9e5602390")) {                    Plotly.newPlot(                        "9cef73c0-923c-4e1b-8275-33d9e5602390",                        [{"customdata":[["Rice Hall",-92],["Rice Hall",-95],["Rice Hall",-85],["Olsson Hall",-113],["Olsson Hall",-115],["Olsson Hall",-109],["Wilsdorf Hall",-94],["Wilsdorf Hall",-92],["Thornton Hall",-102],["Thornton Hall",-98],["Thornton Hall",-93],["Thornton Hall",-97],["Thornton Hall",-90],["Thornton Hall",-87],["Thornton Hall",-93],["Thornton Hall",-72],["Thornton Hall",-89],["Thornton Hall",-111],["Thornton Hall",-99],["Mechanical Engineering",-93],["Mechanical Engineering",-90],["Mechanical Engineering",-88],["Small Hall",-110]],"hovertemplate":"<b>%{hovertext}</b><br><br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G RSSI signal=%{marker.color}<extra></extra>","hovertext":["Rice Hall West","Rice Hall Central","Rice Hall East","Olsson Hall West","Olsson Hall North","Olsson Hall East","Wilsdorf North","Wilsdorf South","A-Wing West","A-Wing Central","A-Wing East","B-Wing","B-Wing","C-Wing","C-Wing","D-Wing","D-Wing","E-Wing","E-Wing","Mech North","Mech Central","Mech South","Small Hall"],"lat":[38.031395,38.031738,38.03175,38.031818,38.032074,38.03199,38.03392,38.033081,38.033329,38.033348,38.03307,38.033257,38.033085,38.032875,38.032612,38.032764,38.032806,38.032623,38.032265,38.032543,38.032852,38.032898,38.032078],"legendgroup":"","lon":[-78.510704,-78.51107,-78.511063,-78.510201,-78.510175,-78.510818,-78.511032,-78.511452,-78.509903,-78.509521,-78.509209,-78.510002,-78.510414,-78.509377,-78.509552,-78.510468,-78.510414,-78.50956,-78.509834,-78.511208,-78.511047,-78.511139,-78.510933],"marker":{"color":[-92,-95,-85,-113,-115,-109,-94,-92,-102,-98,-93,-97,-90,-87,-93,-72,-89,-111,-99,-93,-90,-88,-110],"coloraxis":"coloraxis","opacity":1},"mode":"markers","name":"","showlegend":false,"subplot":"mapbox","type":"scattermapbox"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"t ...

# %% [markdown]
# #### *Second Floor* RSSI Signal

# %%
second_floor = indoors[indoors['Floor'] == '2']
fig = px.scatter_mapbox(second_floor, 
                        lat='Lat', lon='Long', 
                        mapbox_style="stamen-terrain", zoom=16.2,
                        color='4G RSSI signal',
                        color_continuous_scale=px.colors.sequential.Cividis_r,
                        range_color = range_rssi,
                        opacity = 1,
                        hover_name='Description', 
                        hover_data=['Location ID','4G RSSI signal'],
                        title = 'RSSI Signal Strength, Second Floors',
 )
fig.update_layout(mapbox_style = 'carto-positron')
fig.show()
# Out:
# <div>                            <div id="838ae117-9b00-4626-8174-384ee7c6fbf9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("838ae117-9b00-4626-8174-384ee7c6fbf9")) {                    Plotly.newPlot(                        "838ae117-9b00-4626-8174-384ee7c6fbf9",                        [{"customdata":[["Rice Hall",-90],["Rice Hall",-95],["Rice Hall",-102],["Olsson Hall",-96],["Olsson Hall",-100],["Olsson Hall",-98],["Wilsdorf Hall",-100],["Wilsdorf Hall",-93],["Jesser Hall",-85],["Thornton Hall",-89],["Thornton Hall",-92],["Thornton Hall",-88],["Thornton Hall",-91],["Thornton Hall",-85],["Thornton Hall",-80],["Thornton Hall",-85],["Thornton Hall",-78],["Thornton Hall",-100],["Thornton Hall",-96],["Thornton Hall",-87],["Mechanical Engineering",-86],["Mechanical Engineering",-82],["Mechanical Engineering",-79]],"hovertemplate":"<b>%{hovertext}</b><br><br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G RSSI signal=%{marker.color}<extra></extra>","hovertext":["Rice Hall West","Rice Hall Central","Rice Hall East","Olsson Hall West","Olsson Hall North","Olsson Hall East","Wilsdorf North","Wilsdorf South","Jesser Hall","A-Wing West","A-Wing Central","A-Wing East","B-Wing","B-Wing","C-Wing","C-Wing","D-Wing","D-Wing","E-Wing","E-Wing","Mech North","Mech Central","Mech South"],"lat":[38.031395,38.031738,38.03175,38.031818,38.032074,38.03199,38.03392,38.033081,38.033295,38.033329,38.033348,38.03307,38.033276,38.033077,38.032875,38.032612,38.032772,38.03252,38.032623,38.032265,38.032543,38.032852,38.032898],"legendgroup":"","lon":[-78.510704,-78.51107,-78.511063,-78.510201,-78.510175,-78.510818,-78.511032,-78.511452,-78.510803,-78.509903,-78.509521,-78.509209,-78.510002,-78.510414,-78.509377,-78.509552,-78.510468,-78.510414,-78.50956,-78.509834,-78.511208,-78.511047,-78.511139],"marker":{"color":[-90,-95,-102,-96,-100,-98,-100,-93,-85,-89,-92,-88,-91,-85,-80,-85,-78,-100,-96,-87,-86,-82,-79],"coloraxis":"coloraxis","opacity":1},"mode":"markers","name":"","showlegend":false,"subplot":"mapbox","type":"scattermapbox"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"tick ...

# %% [markdown]
# #### *Third Floor* RSSI Signal

# %%
third = indoors[indoors['Floor'] == '3']
fig = px.scatter_mapbox(third, 
                        lat='Lat', lon='Long', 
                        mapbox_style="stamen-terrain", zoom=16.2,
                        color='4G RSSI signal',
                        color_continuous_scale=px.colors.sequential.Cividis_r,
                        range_color = range_rssi,
                        opacity = 1,
                        hover_name='Description', 
                        hover_data=['Location ID','4G RSSI signal'],
                        title = 'RSSI Signal Strenth, Third Floors',
 )
fig.update_layout(mapbox_style = 'carto-positron')
fig.show()
# Out:
# <div>                            <div id="1822ce17-16b0-4c85-b5a5-b417838fb3cb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1822ce17-16b0-4c85-b5a5-b417838fb3cb")) {                    Plotly.newPlot(                        "1822ce17-16b0-4c85-b5a5-b417838fb3cb",                        [{"customdata":[["Rice Hall",-84],["Rice Hall",-83],["Rice Hall",-85],["Wilsdorf Hall",-102],["Wilsdorf Hall",-98],["Jesser Hall",-82],["Thornton Hall",-85],["Thornton Hall",-87]],"hovertemplate":"<b>%{hovertext}</b><br><br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G RSSI signal=%{marker.color}<extra></extra>","hovertext":["Rice Hall West","Rice Hall Central","Rice Hall East","Wilsdorf North","Wilsdorf South","Jesser Hall","E-Wing","E-Wing"],"lat":[38.031395,38.031738,38.03175,38.03392,38.033081,38.033295,38.032623,38.032265],"legendgroup":"","lon":[-78.510704,-78.51107,-78.511063,-78.511032,-78.511452,-78.510803,-78.50956,-78.509834],"marker":{"color":[-84,-83,-85,-102,-98,-82,-85,-87],"coloraxis":"coloraxis","opacity":1},"mode":"markers","name":"","showlegend":false,"subplot":"mapbox","type":"scattermapbox"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type": ...

# %% [markdown]
# #### *Fourth Floor* RSSI Signal

# %%
fourth = indoors[indoors['Floor'] == '4']
fig = px.scatter_mapbox(fourth, 
                        lat='Lat', lon='Long', 
                        mapbox_style="stamen-terrain", zoom=18.2,
                        color='4G RSSI signal',
                        color_continuous_scale=px.colors.sequential.Cividis_r,
                        range_color = range_rssi,
                        opacity = 1,
                        hover_name='Description', 
                        hover_data=['Location ID','4G RSSI signal'],
                        title = 'RSSI Signal Strength, Fourth Floors',
 )
fig.update_layout(mapbox_style = 'carto-positron')
fig.show()
# Out:
# <div>                            <div id="f3178bf8-4fda-4823-ba78-10068ed9cc07" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f3178bf8-4fda-4823-ba78-10068ed9cc07")) {                    Plotly.newPlot(                        "f3178bf8-4fda-4823-ba78-10068ed9cc07",                        [{"customdata":[["Rice Hall",-81],["Rice Hall",-77],["Rice Hall",-84]],"hovertemplate":"<b>%{hovertext}</b><br><br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G RSSI signal=%{marker.color}<extra></extra>","hovertext":["Rice Hall West","Rice Hall Central","Rice Hall East"],"lat":[38.031395,38.031738,38.03175],"legendgroup":"","lon":[-78.510704,-78.51107,-78.511063],"marker":{"color":[-81,-77,-84],"coloraxis":"coloraxis","opacity":1},"mode":"markers","name":"","showlegend":false,"subplot":"mapbox","type":"scattermapbox"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode" ...

# %%
fifth = indoors[indoors['Floor'] == '5']
fig = px.scatter_mapbox(fifth, 
                        lat='Lat', lon='Long', 
                        mapbox_style="stamen-terrain", zoom=18.2,
                        color='4G RSSI signal',
                        color_continuous_scale=px.colors.sequential.Cividis_r,
                        range_color = range_rssi,
                        opacity = 1,
                        hover_name='Description', 
                        hover_data=['Location ID','4G RSSI signal'],
                        title = 'RSSI Signal Strength, Fourth Floors',
 )
fig.update_layout(mapbox_style = 'carto-positron')
fig.show()
# Out:
# <div>                            <div id="d1dcdaf2-c48c-4cd2-af7f-9ff5bd3b25c8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d1dcdaf2-c48c-4cd2-af7f-9ff5bd3b25c8")) {                    Plotly.newPlot(                        "d1dcdaf2-c48c-4cd2-af7f-9ff5bd3b25c8",                        [{"customdata":[["Rice Hall",-91],["Rice Hall",-89],["Rice Hall",-71]],"hovertemplate":"<b>%{hovertext}</b><br><br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G RSSI signal=%{marker.color}<extra></extra>","hovertext":["Rice Hall West","Rice Hall Central","Rice Hall East"],"lat":[38.031395,38.031738,38.03175],"legendgroup":"","lon":[-78.510704,-78.51107,-78.511063],"marker":{"color":[-91,-89,-71],"coloraxis":"coloraxis","opacity":1},"mode":"markers","name":"","showlegend":false,"subplot":"mapbox","type":"scattermapbox"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode" ...

# %% [markdown]
# ## Download Rates by Floor

# %%
# Out:
# 16.468354430379755

# %%
fig = px.histogram(indoors, '4G download rate', 
                   color = 'Floor', 
                   title='Histogram of 4G download rate, by floor',
                   hover_data = ['Description', '4G RSSI signal']
                  )
fig.update_traces(xbins=dict( # bins used for histogram
        start=0.0,
        end=90.0,
        size=5
    ))
fig.show()
# Out:
# <div>                            <div id="0219c2a0-15da-48db-aecc-40f99e2f0098" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0219c2a0-15da-48db-aecc-40f99e2f0098")) {                    Plotly.newPlot(                        "0219c2a0-15da-48db-aecc-40f99e2f0098",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Floor=5<br>4G download rate=%{x}<br>count=%{y}<extra></extra>","legendgroup":"5","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"5","offsetgroup":"5","orientation":"v","showlegend":true,"x":[73.4,79.5,56.6],"xaxis":"x","yaxis":"y","type":"histogram","xbins":{"end":90.0,"size":5,"start":0.0}},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Floor=4<br>4G download rate=%{x}<br>count=%{y}<extra></extra>","legendgroup":"4","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"4","offsetgroup":"4","orientation":"v","showlegend":true,"x":[69.3,55.3,41.6],"xaxis":"x","yaxis":"y","type":"histogram","xbins":{"end":90.0,"size":5,"start":0.0}},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Floor=3<br>4G download rate=%{x}<br>count=%{y}<extra></extra>","legendgroup":"3","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"3","offsetgroup":"3","orientation":"v","showlegend":true,"x":[52.2,58.9,80.3,0.5,1.7,1.9,2.1,4.3],"xaxis":"x","yaxis":"y","type":"histogram","xbins":{"end":90.0,"size":5,"start":0.0}},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Floor=2<br>4G download rate=%{x}<br>count=%{y}<extra></extra>","legendgroup":"2","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"2","offsetgroup":"2","orientation":"v","showlegend":true,"x":[77.7,76.6,65.3,1.8,0.7,2.9,1.0,0.6,1.7,1.0,2.5,0.9,3.8,6.2,0.0,5.1,0.4,0.7,0.0,1.8,5.3,5.4,8.2],"xaxis":"x","yaxis":"y","type":"histogram","xbins":{"end":90.0,"size":5,"start":0.0}},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Floor=1<br>4G download rate=%{x}<br>count=%{y}<extra></extra>","legendgroup":"1","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"1","offsetgroup":"1","orientation":"v","showlegend":true,"x":[63.0,76.4,63.7,1.4,0.9,3.5,1.4,2.9,2.0,0.3,1.1,0.1,1.0,0.3,0.7,0.5,2.2,0.0,1.3,6.4,4.8,1.7,16.1],"xaxis":"x","yaxis":"y","type":"histogram","xbins":{"end":90.0,"size":5,"start":0.0}},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Floor=0<br>4G download rate=%{x}<br>count=%{y}<extra></extra>","legendgroup":"0","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"0","offsetgroup":"0","orientation":"v","showlegend":true,"x":[45.6,63.3,77.5,1.7,1.3,0.4,2.5,0.0,0.4,0.0,0.7,0.1,0.0,1.7,1.5],"xaxis":"x","yaxis":"y","type":"histogram","xbins":{"end":90.0,"size":5,"start":0.0}},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Floor=A<br>4G download rate=%{x}<br>count=%{y}<extra></extra>","legendgroup":"A","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"A","offsetgroup":"A","orientation":"v","showlegend":true,"x":[0.0,5.4],"xaxis":"x","yaxis":"y","type":"histogram","xbins":{"end":90.0,"size":5,"start":0.0}},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Floor=B<br>4G download rate=%{x}<br>count=%{y}<extra></extra>","legendgroup":"B","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"B","offsetgroup":"B","orientation":"v","showlegend":true,"x":[0.0,0.0],"xaxis":"x","yaxis":"y","type":"histogram","xbins":{"end":90.0,"size":5,"start":0.0}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7 ...

# %%
download_max = indoors['4G download rate'].max()
download_min = indoors['4G download rate'].min()
range_down = [download_min, download_max] 
print("MAX Upload Rate: ", download_max)
print("MAX Upload Rate: ", download_min)
# Out:
# MAX Upload Rate:  80.3
# MAX Upload Rate:  0.0

# %%
basement_data = indoors[(indoors['Floor'] == '0')| (indoors['Floor'] == 'A' )| (indoors['Floor'] == 'B')]
fig = px.scatter_mapbox(basement_data, 
                        lat='Lat', lon='Long', 
                        mapbox_style="stamen-terrain", zoom=16.2,
                        size = '4G download rate',
                        color= 'Description',
                        opacity = 0.5,
                        hover_name='Description', 
                        hover_data=['Location ID','4G download rate', '4G upload rate'],
                        title = '4G Download Rate - indoors, Basement Floors',
 )
fig.update_layout(mapbox_style = 'carto-positron')
fig.show()
# Out:
# <div>                            <div id="78e6bef9-c433-4f23-b664-5730854fb847" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("78e6bef9-c433-4f23-b664-5730854fb847")) {                    Plotly.newPlot(                        "78e6bef9-c433-4f23-b664-5730854fb847",                        [{"customdata":[["Rice Hall",45.6,7.4]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Rice Hall West<br>4G download rate=%{customdata[1]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G upload rate=%{customdata[2]}<extra></extra>","hovertext":["Rice Hall West"],"lat":[38.031395],"legendgroup":"Rice Hall West","lon":[-78.510704],"marker":{"color":"#636efa","opacity":0.5,"size":[45.6],"sizemode":"area","sizeref":0.19375},"mode":"markers","name":"Rice Hall West","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["Rice Hall",63.3,28.0]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Rice Hall Central<br>4G download rate=%{customdata[1]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G upload rate=%{customdata[2]}<extra></extra>","hovertext":["Rice Hall Central"],"lat":[38.031738],"legendgroup":"Rice Hall Central","lon":[-78.51107],"marker":{"color":"#EF553B","opacity":0.5,"size":[63.3],"sizemode":"area","sizeref":0.19375},"mode":"markers","name":"Rice Hall Central","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["Rice Hall",77.5,23.0]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Rice Hall East<br>4G download rate=%{customdata[1]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G upload rate=%{customdata[2]}<extra></extra>","hovertext":["Rice Hall East"],"lat":[38.03175],"legendgroup":"Rice Hall East","lon":[-78.511063],"marker":{"color":"#00cc96","opacity":0.5,"size":[77.5],"sizemode":"area","sizeref":0.19375},"mode":"markers","name":"Rice Hall East","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["Olsson Hall",1.7,4.7]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Olsson Hall West<br>4G download rate=%{customdata[1]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G upload rate=%{customdata[2]}<extra></extra>","hovertext":["Olsson Hall West"],"lat":[38.031818],"legendgroup":"Olsson Hall West","lon":[-78.510201],"marker":{"color":"#ab63fa","opacity":0.5,"size":[1.7],"sizemode":"area","sizeref":0.19375},"mode":"markers","name":"Olsson Hall West","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["Olsson Hall",1.3,4.7]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Olsson Hall North<br>4G download rate=%{customdata[1]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G upload rate=%{customdata[2]}<extra></extra>","hovertext":["Olsson Hall North"],"lat":[38.032074],"legendgroup":"Olsson Hall North","lon":[-78.510175],"marker":{"color":"#FFA15A","opacity":0.5,"size":[1.3],"sizemode":"area","sizeref":0.19375},"mode":"markers","name":"Olsson Hall North","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["Olsson Hall",0.4,4.7]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Olsson Hall East<br>4G download rate=%{customdata[1]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G upload rate=%{customdata[2]}<extra></extra>","hovertext":["Olsson Hall East"],"lat":[38.03199],"legendgroup":"Olsson Hall East","lon":[-78.510818],"marker":{"color":"#19d3f3","opacity":0.5,"size":[0.4],"sizemode":"area","sizeref":0.19375},"mode":"markers","name":"Olsson Hall East","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["Wilsdorf Hall",0.0,0.0],["Wilsdorf Hall",0.0,0.0]],"hovertemplate":"<b>%{hovertext}</b><br><br> ...

# %%
first = indoors[indoors['Floor'] == '1']
fig = px.scatter_mapbox(first, 
                        lat='Lat', lon='Long', 
                        mapbox_style="stamen-terrain", zoom=16.0,
                        size='4G download rate',
                        color = 'Description',
                        opacity = 1,
                        hover_name='Description', 
                        hover_data=['Location ID','4G download rate', '4G upload rate'],
                        title = '4G Download Rate - indoors, First Floors',
 )
fig.update_layout(mapbox_style = 'carto-positron')
fig.show()
# Out:
# <div>                            <div id="3ebb9ac6-0a5f-412e-9d10-eab9239b9b6c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3ebb9ac6-0a5f-412e-9d10-eab9239b9b6c")) {                    Plotly.newPlot(                        "3ebb9ac6-0a5f-412e-9d10-eab9239b9b6c",                        [{"customdata":[["Rice Hall",63.0,12.1]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Rice Hall West<br>4G download rate=%{customdata[1]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G upload rate=%{customdata[2]}<extra></extra>","hovertext":["Rice Hall West"],"lat":[38.031395],"legendgroup":"Rice Hall West","lon":[-78.510704],"marker":{"color":"#636efa","opacity":1,"size":[63.0],"sizemode":"area","sizeref":0.191},"mode":"markers","name":"Rice Hall West","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["Rice Hall",76.4,22.1]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Rice Hall Central<br>4G download rate=%{customdata[1]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G upload rate=%{customdata[2]}<extra></extra>","hovertext":["Rice Hall Central"],"lat":[38.031738],"legendgroup":"Rice Hall Central","lon":[-78.51107],"marker":{"color":"#EF553B","opacity":1,"size":[76.4],"sizemode":"area","sizeref":0.191},"mode":"markers","name":"Rice Hall Central","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["Rice Hall",63.7,29.4]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Rice Hall East<br>4G download rate=%{customdata[1]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G upload rate=%{customdata[2]}<extra></extra>","hovertext":["Rice Hall East"],"lat":[38.03175],"legendgroup":"Rice Hall East","lon":[-78.511063],"marker":{"color":"#00cc96","opacity":1,"size":[63.7],"sizemode":"area","sizeref":0.191},"mode":"markers","name":"Rice Hall East","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["Olsson Hall",1.4,4.6]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Olsson Hall West<br>4G download rate=%{customdata[1]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G upload rate=%{customdata[2]}<extra></extra>","hovertext":["Olsson Hall West"],"lat":[38.031818],"legendgroup":"Olsson Hall West","lon":[-78.510201],"marker":{"color":"#ab63fa","opacity":1,"size":[1.4],"sizemode":"area","sizeref":0.191},"mode":"markers","name":"Olsson Hall West","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["Olsson Hall",0.9,4.6]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Olsson Hall North<br>4G download rate=%{customdata[1]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G upload rate=%{customdata[2]}<extra></extra>","hovertext":["Olsson Hall North"],"lat":[38.032074],"legendgroup":"Olsson Hall North","lon":[-78.510175],"marker":{"color":"#FFA15A","opacity":1,"size":[0.9],"sizemode":"area","sizeref":0.191},"mode":"markers","name":"Olsson Hall North","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["Olsson Hall",3.5,2.8]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Olsson Hall East<br>4G download rate=%{customdata[1]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G upload rate=%{customdata[2]}<extra></extra>","hovertext":["Olsson Hall East"],"lat":[38.03199],"legendgroup":"Olsson Hall East","lon":[-78.510818],"marker":{"color":"#19d3f3","opacity":1,"size":[3.5],"sizemode":"area","sizeref":0.191},"mode":"markers","name":"Olsson Hall East","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["Wilsdorf Hall",1.4,4.6]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Wilsdorf North<br>4G download rate=%{ ...

# %%
second = indoors[indoors['Floor'] == '2']
fig = px.scatter_mapbox(second, 
                        lat='Lat', lon='Long', 
                        mapbox_style="stamen-terrain", zoom=16.0,
                        color = 'Description',
                        size='4G download rate',
                        opacity = 0.7,
                        hover_name='Description', 
                        hover_data=['Location ID','4G download rate', '4G upload rate'],
                        title = '4G Download Rate - indoors, Second Floors',
 )
fig.update_layout(mapbox_style = 'carto-positron')
fig.show()
# Out:
# <div>                            <div id="c8060597-4c1d-4722-9f3f-81da41df7d76" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c8060597-4c1d-4722-9f3f-81da41df7d76")) {                    Plotly.newPlot(                        "c8060597-4c1d-4722-9f3f-81da41df7d76",                        [{"customdata":[["Rice Hall",77.7,14.3]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Rice Hall West<br>4G download rate=%{customdata[1]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G upload rate=%{customdata[2]}<extra></extra>","hovertext":["Rice Hall West"],"lat":[38.031395],"legendgroup":"Rice Hall West","lon":[-78.510704],"marker":{"color":"#636efa","opacity":0.7,"size":[77.7],"sizemode":"area","sizeref":0.19425},"mode":"markers","name":"Rice Hall West","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["Rice Hall",76.6,30.8]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Rice Hall Central<br>4G download rate=%{customdata[1]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G upload rate=%{customdata[2]}<extra></extra>","hovertext":["Rice Hall Central"],"lat":[38.031738],"legendgroup":"Rice Hall Central","lon":[-78.51107],"marker":{"color":"#EF553B","opacity":0.7,"size":[76.6],"sizemode":"area","sizeref":0.19425},"mode":"markers","name":"Rice Hall Central","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["Rice Hall",65.3,23.5]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Rice Hall East<br>4G download rate=%{customdata[1]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G upload rate=%{customdata[2]}<extra></extra>","hovertext":["Rice Hall East"],"lat":[38.03175],"legendgroup":"Rice Hall East","lon":[-78.511063],"marker":{"color":"#00cc96","opacity":0.7,"size":[65.3],"sizemode":"area","sizeref":0.19425},"mode":"markers","name":"Rice Hall East","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["Olsson Hall",1.8,4.6]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Olsson Hall West<br>4G download rate=%{customdata[1]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G upload rate=%{customdata[2]}<extra></extra>","hovertext":["Olsson Hall West"],"lat":[38.031818],"legendgroup":"Olsson Hall West","lon":[-78.510201],"marker":{"color":"#ab63fa","opacity":0.7,"size":[1.8],"sizemode":"area","sizeref":0.19425},"mode":"markers","name":"Olsson Hall West","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["Olsson Hall",0.7,4.7]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Olsson Hall North<br>4G download rate=%{customdata[1]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G upload rate=%{customdata[2]}<extra></extra>","hovertext":["Olsson Hall North"],"lat":[38.032074],"legendgroup":"Olsson Hall North","lon":[-78.510175],"marker":{"color":"#FFA15A","opacity":0.7,"size":[0.7],"sizemode":"area","sizeref":0.19425},"mode":"markers","name":"Olsson Hall North","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["Olsson Hall",2.9,4.7]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Olsson Hall East<br>4G download rate=%{customdata[1]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G upload rate=%{customdata[2]}<extra></extra>","hovertext":["Olsson Hall East"],"lat":[38.03199],"legendgroup":"Olsson Hall East","lon":[-78.510818],"marker":{"color":"#19d3f3","opacity":0.7,"size":[2.9],"sizemode":"area","sizeref":0.19425},"mode":"markers","name":"Olsson Hall East","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["Wilsdorf Hall",1.0,4.7]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Wilsdorf Nort ...

# %%
third = indoors[indoors['Floor'] == '3']
fig = px.scatter_mapbox(third, 
                        lat='Lat', lon='Long', 
                        mapbox_style="stamen-terrain", zoom=16.0,
                        color = 'Description',
                        size='4G download rate',
                        opacity = 0.7,
                        hover_name='Description', 
                        hover_data=['Location ID','4G download rate', '4G upload rate'],
                        title = '4G Download Rate - indoors, Second Floors',
 )
fig.update_layout(mapbox_style = 'carto-positron')
fig.show()
# Out:
# <div>                            <div id="6eb63b4a-78e4-4e27-aacb-07395fa5a600" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6eb63b4a-78e4-4e27-aacb-07395fa5a600")) {                    Plotly.newPlot(                        "6eb63b4a-78e4-4e27-aacb-07395fa5a600",                        [{"customdata":[["Rice Hall",52.2,6.9]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Rice Hall West<br>4G download rate=%{customdata[1]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G upload rate=%{customdata[2]}<extra></extra>","hovertext":["Rice Hall West"],"lat":[38.031395],"legendgroup":"Rice Hall West","lon":[-78.510704],"marker":{"color":"#636efa","opacity":0.7,"size":[52.2],"sizemode":"area","sizeref":0.20074999999999998},"mode":"markers","name":"Rice Hall West","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["Rice Hall",58.9,11.7]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Rice Hall Central<br>4G download rate=%{customdata[1]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G upload rate=%{customdata[2]}<extra></extra>","hovertext":["Rice Hall Central"],"lat":[38.031738],"legendgroup":"Rice Hall Central","lon":[-78.51107],"marker":{"color":"#EF553B","opacity":0.7,"size":[58.9],"sizemode":"area","sizeref":0.20074999999999998},"mode":"markers","name":"Rice Hall Central","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["Rice Hall",80.3,26.6]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Rice Hall East<br>4G download rate=%{customdata[1]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G upload rate=%{customdata[2]}<extra></extra>","hovertext":["Rice Hall East"],"lat":[38.03175],"legendgroup":"Rice Hall East","lon":[-78.511063],"marker":{"color":"#00cc96","opacity":0.7,"size":[80.3],"sizemode":"area","sizeref":0.20074999999999998},"mode":"markers","name":"Rice Hall East","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["Wilsdorf Hall",0.5,4.6]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Wilsdorf North<br>4G download rate=%{customdata[1]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G upload rate=%{customdata[2]}<extra></extra>","hovertext":["Wilsdorf North"],"lat":[38.03392],"legendgroup":"Wilsdorf North","lon":[-78.511032],"marker":{"color":"#ab63fa","opacity":0.7,"size":[0.5],"sizemode":"area","sizeref":0.20074999999999998},"mode":"markers","name":"Wilsdorf North","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["Wilsdorf Hall",1.7,4.7]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Wilsdorf South<br>4G download rate=%{customdata[1]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G upload rate=%{customdata[2]}<extra></extra>","hovertext":["Wilsdorf South"],"lat":[38.033081],"legendgroup":"Wilsdorf South","lon":[-78.511452],"marker":{"color":"#FFA15A","opacity":0.7,"size":[1.7],"sizemode":"area","sizeref":0.20074999999999998},"mode":"markers","name":"Wilsdorf South","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["Jesser Hall",1.9,4.6]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Jesser Hall<br>4G download rate=%{customdata[1]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G upload rate=%{customdata[2]}<extra></extra>","hovertext":["Jesser Hall"],"lat":[38.033295],"legendgroup":"Jesser Hall","lon":[-78.510803],"marker":{"color":"#19d3f3","opacity":0.7,"size":[1.9],"sizemode":"area","sizeref":0.20074999999999998},"mode":"markers","name":"Jesser Hall","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["Thornton Hall",2.1,4.7],["Thornton Hall",4.3,4.7]],"hoverte ...

# %%
fourth = indoors[indoors['Floor'] == '4']
fig = px.scatter_mapbox(fourth, 
                        lat='Lat', lon='Long', 
                        mapbox_style="stamen-terrain", zoom=18.0,
                        color = 'Description',
                        size='4G download rate',
                        opacity = 1,
                        hover_name='Description', 
                        hover_data=['Location ID','4G download rate', '4G upload rate'],
                        title = '4G Download Rate - indoors, Fourth Floors',
 )
fig.update_layout(mapbox_style = 'carto-positron')
fig.show()
# Out:
# <div>                            <div id="d985766e-d57a-4ae7-a275-efc5e6212821" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d985766e-d57a-4ae7-a275-efc5e6212821")) {                    Plotly.newPlot(                        "d985766e-d57a-4ae7-a275-efc5e6212821",                        [{"customdata":[["Rice Hall",69.3,19.6]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Rice Hall West<br>4G download rate=%{customdata[1]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G upload rate=%{customdata[2]}<extra></extra>","hovertext":["Rice Hall West"],"lat":[38.031395],"legendgroup":"Rice Hall West","lon":[-78.510704],"marker":{"color":"#636efa","opacity":1,"size":[69.3],"sizemode":"area","sizeref":0.17325},"mode":"markers","name":"Rice Hall West","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["Rice Hall",55.3,19.4]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Rice Hall Central<br>4G download rate=%{customdata[1]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G upload rate=%{customdata[2]}<extra></extra>","hovertext":["Rice Hall Central"],"lat":[38.031738],"legendgroup":"Rice Hall Central","lon":[-78.51107],"marker":{"color":"#EF553B","opacity":1,"size":[55.3],"sizemode":"area","sizeref":0.17325},"mode":"markers","name":"Rice Hall Central","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["Rice Hall",41.6,15.7]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Rice Hall East<br>4G download rate=%{customdata[1]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G upload rate=%{customdata[2]}<extra></extra>","hovertext":["Rice Hall East"],"lat":[38.03175],"legendgroup":"Rice Hall East","lon":[-78.511063],"marker":{"color":"#00cc96","opacity":1,"size":[41.6],"sizemode":"area","sizeref":0.17325},"mode":"markers","name":"Rice Hall East","showlegend":true,"subplot":"mapbox","type":"scattermapbox"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d ...

# %%
fifth = indoors[indoors['Floor'] == '5']
fig = px.scatter_mapbox(fifth, 
                        lat='Lat', lon='Long', 
                        mapbox_style="stamen-terrain", zoom=18.0,
                        color = 'Description',
                        size='4G download rate',
                        opacity = 1,
                        hover_name='Description', 
                        hover_data=['Location ID','4G download rate', '4G upload rate'],
                        title = '4G Download Rate - indoors, Fifth Floors',
 )
fig.update_layout(mapbox_style = 'carto-positron')
fig.show()
# Out:
# <div>                            <div id="de152dc3-0d43-4aa2-9743-0d3e50743978" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("de152dc3-0d43-4aa2-9743-0d3e50743978")) {                    Plotly.newPlot(                        "de152dc3-0d43-4aa2-9743-0d3e50743978",                        [{"customdata":[["Rice Hall",73.4,33.5]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Rice Hall West<br>4G download rate=%{customdata[1]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G upload rate=%{customdata[2]}<extra></extra>","hovertext":["Rice Hall West"],"lat":[38.031395],"legendgroup":"Rice Hall West","lon":[-78.510704],"marker":{"color":"#636efa","opacity":1,"size":[73.4],"sizemode":"area","sizeref":0.19875},"mode":"markers","name":"Rice Hall West","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["Rice Hall",79.5,22.8]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Rice Hall Central<br>4G download rate=%{customdata[1]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G upload rate=%{customdata[2]}<extra></extra>","hovertext":["Rice Hall Central"],"lat":[38.031738],"legendgroup":"Rice Hall Central","lon":[-78.51107],"marker":{"color":"#EF553B","opacity":1,"size":[79.5],"sizemode":"area","sizeref":0.19875},"mode":"markers","name":"Rice Hall Central","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["Rice Hall",56.6,20.0]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Rice Hall East<br>4G download rate=%{customdata[1]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G upload rate=%{customdata[2]}<extra></extra>","hovertext":["Rice Hall East"],"lat":[38.03175],"legendgroup":"Rice Hall East","lon":[-78.511063],"marker":{"color":"#00cc96","opacity":1,"size":[56.6],"sizemode":"area","sizeref":0.19875},"mode":"markers","name":"Rice Hall East","showlegend":true,"subplot":"mapbox","type":"scattermapbox"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d ...

# %% [markdown]
# ## Obsevation:

# %%
fig = px.histogram(indoors, '4G upload rate', 
                   color = 'Floor', 
                   title='Histogram of 4G upload rate, by floor',
                   hover_data = ['Description', '4G RSSI signal']
                  )
fig.update_traces(xbins=dict( # bins used for histogram
        start=0.0,
        size=2
    ))
#labels={'count':'number of sessions',
#                      'ProductRelated_Duration':'Time Spent Viewing Product-related Webpage',
#                      'Revenue':'Successful Sale',
#                      1:'Success',
#                      0:'No success'
#                     }
fig.show()
# Out:
# <div>                            <div id="4dcd90f8-eb3a-4ec2-b05d-bb70541272c9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4dcd90f8-eb3a-4ec2-b05d-bb70541272c9")) {                    Plotly.newPlot(                        "4dcd90f8-eb3a-4ec2-b05d-bb70541272c9",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Floor=5<br>4G upload rate=%{x}<br>count=%{y}<extra></extra>","legendgroup":"5","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"5","offsetgroup":"5","orientation":"v","showlegend":true,"x":[33.5,22.8,20.0],"xaxis":"x","yaxis":"y","type":"histogram","xbins":{"size":2,"start":0.0}},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Floor=4<br>4G upload rate=%{x}<br>count=%{y}<extra></extra>","legendgroup":"4","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"4","offsetgroup":"4","orientation":"v","showlegend":true,"x":[19.6,19.4,15.7],"xaxis":"x","yaxis":"y","type":"histogram","xbins":{"size":2,"start":0.0}},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Floor=3<br>4G upload rate=%{x}<br>count=%{y}<extra></extra>","legendgroup":"3","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"3","offsetgroup":"3","orientation":"v","showlegend":true,"x":[6.9,11.7,26.6,4.6,4.7,4.6,4.7,4.7],"xaxis":"x","yaxis":"y","type":"histogram","xbins":{"size":2,"start":0.0}},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Floor=2<br>4G upload rate=%{x}<br>count=%{y}<extra></extra>","legendgroup":"2","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"2","offsetgroup":"2","orientation":"v","showlegend":true,"x":[14.3,30.8,23.5,4.6,4.7,4.7,4.7,4.6,5.6,4.7,4.7,4.7,4.7,4.6,0.0,4.7,4.7,4.6,0.0,5.8,4.6,4.7,7.0],"xaxis":"x","yaxis":"y","type":"histogram","xbins":{"size":2,"start":0.0}},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Floor=1<br>4G upload rate=%{x}<br>count=%{y}<extra></extra>","legendgroup":"1","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"1","offsetgroup":"1","orientation":"v","showlegend":true,"x":[12.1,22.1,29.4,4.6,4.6,2.8,4.6,4.7,4.6,4.7,4.7,4.7,4.4,2.8,0.5,14.0,4.7,12.1,4.7,5.8,3.3,4.7,7.0],"xaxis":"x","yaxis":"y","type":"histogram","xbins":{"size":2,"start":0.0}},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Floor=0<br>4G upload rate=%{x}<br>count=%{y}<extra></extra>","legendgroup":"0","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"0","offsetgroup":"0","orientation":"v","showlegend":true,"x":[7.4,28.0,23.0,4.7,4.7,4.7,4.7,0.0,4.6,0.0,4.7,4.7,0.0,4.6,7.0],"xaxis":"x","yaxis":"y","type":"histogram","xbins":{"size":2,"start":0.0}},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Floor=A<br>4G upload rate=%{x}<br>count=%{y}<extra></extra>","legendgroup":"A","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"A","offsetgroup":"A","orientation":"v","showlegend":true,"x":[0.0,4.7],"xaxis":"x","yaxis":"y","type":"histogram","xbins":{"size":2,"start":0.0}},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Floor=B<br>4G upload rate=%{x}<br>count=%{y}<extra></extra>","legendgroup":"B","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"B","offsetgroup":"B","orientation":"v","showlegend":true,"x":[0.0,0.0],"xaxis":"x","yaxis":"y","type":"histogram","xbins":{"size":2,"start":0.0}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choro ...

# %%
upload_max = indoors['4G upload rate'].max()
upload_min = indoors['4G upload rate'].min()
range_up = [upload_min, upload_max] 
print("MAX Upload Rate: ", upload_max)
print("MAX Upload Rate: ", upload_min)
# Out:
# MAX Upload Rate:  33.5
# MAX Upload Rate:  0.0

# %%
basement_data = indoors[(indoors['Floor'] == '0')| (indoors['Floor'] == 'A' )| (indoors['Floor'] == 'B')]
fig = px.scatter_mapbox(basement_data, 
                        lat='Lat', lon='Long', 
                        mapbox_style="stamen-terrain", zoom=16.2,
                        size = '4G upload rate',
                        color= 'Description',
                        opacity = 0.5,
                        hover_name='Description', 
                        hover_data=['Location ID','4G download rate', '4G upload rate'],
                        title = '4G Download Rate - indoors, Basement Floors',
 )
fig.update_layout(mapbox_style = 'carto-positron')
fig.show()
# Out:
# <div>                            <div id="cf797e19-e102-4ff2-9f71-c51f6ee9321a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cf797e19-e102-4ff2-9f71-c51f6ee9321a")) {                    Plotly.newPlot(                        "cf797e19-e102-4ff2-9f71-c51f6ee9321a",                        [{"customdata":[["Rice Hall",45.6,7.4]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Rice Hall West<br>4G upload rate=%{customdata[2]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G download rate=%{customdata[1]}<extra></extra>","hovertext":["Rice Hall West"],"lat":[38.031395],"legendgroup":"Rice Hall West","lon":[-78.510704],"marker":{"color":"#636efa","opacity":0.5,"size":[7.4],"sizemode":"area","sizeref":0.07},"mode":"markers","name":"Rice Hall West","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["Rice Hall",63.3,28.0]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Rice Hall Central<br>4G upload rate=%{customdata[2]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G download rate=%{customdata[1]}<extra></extra>","hovertext":["Rice Hall Central"],"lat":[38.031738],"legendgroup":"Rice Hall Central","lon":[-78.51107],"marker":{"color":"#EF553B","opacity":0.5,"size":[28.0],"sizemode":"area","sizeref":0.07},"mode":"markers","name":"Rice Hall Central","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["Rice Hall",77.5,23.0]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Rice Hall East<br>4G upload rate=%{customdata[2]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G download rate=%{customdata[1]}<extra></extra>","hovertext":["Rice Hall East"],"lat":[38.03175],"legendgroup":"Rice Hall East","lon":[-78.511063],"marker":{"color":"#00cc96","opacity":0.5,"size":[23.0],"sizemode":"area","sizeref":0.07},"mode":"markers","name":"Rice Hall East","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["Olsson Hall",1.7,4.7]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Olsson Hall West<br>4G upload rate=%{customdata[2]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G download rate=%{customdata[1]}<extra></extra>","hovertext":["Olsson Hall West"],"lat":[38.031818],"legendgroup":"Olsson Hall West","lon":[-78.510201],"marker":{"color":"#ab63fa","opacity":0.5,"size":[4.7],"sizemode":"area","sizeref":0.07},"mode":"markers","name":"Olsson Hall West","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["Olsson Hall",1.3,4.7]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Olsson Hall North<br>4G upload rate=%{customdata[2]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G download rate=%{customdata[1]}<extra></extra>","hovertext":["Olsson Hall North"],"lat":[38.032074],"legendgroup":"Olsson Hall North","lon":[-78.510175],"marker":{"color":"#FFA15A","opacity":0.5,"size":[4.7],"sizemode":"area","sizeref":0.07},"mode":"markers","name":"Olsson Hall North","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["Olsson Hall",0.4,4.7]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Olsson Hall East<br>4G upload rate=%{customdata[2]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G download rate=%{customdata[1]}<extra></extra>","hovertext":["Olsson Hall East"],"lat":[38.03199],"legendgroup":"Olsson Hall East","lon":[-78.510818],"marker":{"color":"#19d3f3","opacity":0.5,"size":[4.7],"sizemode":"area","sizeref":0.07},"mode":"markers","name":"Olsson Hall East","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["Wilsdorf Hall",0.0,0.0],["Wilsdorf Hall",0.0,0.0]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Wilsdor ...

# %%
fifth = indoors[indoors['Floor'] == '1']
fig = px.scatter_mapbox(fifth, 
                        lat='Lat', lon='Long', 
                        mapbox_style="stamen-terrain", zoom=16.0,
                        color = 'Description',
                        size='4G upload rate',
                        opacity = 0.7,
                        hover_name='Description', 
                        hover_data=['Location ID','4G download rate', '4G upload rate'],
                        title = '4G Upload Rate - indoors, First Floors',
 )
fig.update_layout(mapbox_style = 'carto-positron')
fig.show()
# Out:
# <div>                            <div id="62edd66f-950f-416f-a466-773a942ec62a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("62edd66f-950f-416f-a466-773a942ec62a")) {                    Plotly.newPlot(                        "62edd66f-950f-416f-a466-773a942ec62a",                        [{"customdata":[["Rice Hall",63.0,12.1]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Rice Hall West<br>4G upload rate=%{customdata[2]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G download rate=%{customdata[1]}<extra></extra>","hovertext":["Rice Hall West"],"lat":[38.031395],"legendgroup":"Rice Hall West","lon":[-78.510704],"marker":{"color":"#636efa","opacity":0.7,"size":[12.1],"sizemode":"area","sizeref":0.0735},"mode":"markers","name":"Rice Hall West","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["Rice Hall",76.4,22.1]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Rice Hall Central<br>4G upload rate=%{customdata[2]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G download rate=%{customdata[1]}<extra></extra>","hovertext":["Rice Hall Central"],"lat":[38.031738],"legendgroup":"Rice Hall Central","lon":[-78.51107],"marker":{"color":"#EF553B","opacity":0.7,"size":[22.1],"sizemode":"area","sizeref":0.0735},"mode":"markers","name":"Rice Hall Central","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["Rice Hall",63.7,29.4]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Rice Hall East<br>4G upload rate=%{customdata[2]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G download rate=%{customdata[1]}<extra></extra>","hovertext":["Rice Hall East"],"lat":[38.03175],"legendgroup":"Rice Hall East","lon":[-78.511063],"marker":{"color":"#00cc96","opacity":0.7,"size":[29.4],"sizemode":"area","sizeref":0.0735},"mode":"markers","name":"Rice Hall East","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["Olsson Hall",1.4,4.6]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Olsson Hall West<br>4G upload rate=%{customdata[2]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G download rate=%{customdata[1]}<extra></extra>","hovertext":["Olsson Hall West"],"lat":[38.031818],"legendgroup":"Olsson Hall West","lon":[-78.510201],"marker":{"color":"#ab63fa","opacity":0.7,"size":[4.6],"sizemode":"area","sizeref":0.0735},"mode":"markers","name":"Olsson Hall West","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["Olsson Hall",0.9,4.6]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Olsson Hall North<br>4G upload rate=%{customdata[2]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G download rate=%{customdata[1]}<extra></extra>","hovertext":["Olsson Hall North"],"lat":[38.032074],"legendgroup":"Olsson Hall North","lon":[-78.510175],"marker":{"color":"#FFA15A","opacity":0.7,"size":[4.6],"sizemode":"area","sizeref":0.0735},"mode":"markers","name":"Olsson Hall North","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["Olsson Hall",3.5,2.8]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Olsson Hall East<br>4G upload rate=%{customdata[2]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G download rate=%{customdata[1]}<extra></extra>","hovertext":["Olsson Hall East"],"lat":[38.03199],"legendgroup":"Olsson Hall East","lon":[-78.510818],"marker":{"color":"#19d3f3","opacity":0.7,"size":[2.8],"sizemode":"area","sizeref":0.0735},"mode":"markers","name":"Olsson Hall East","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["Wilsdorf Hall",1.4,4.6]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Wilsdorf North<br>4 ...

# %%
fifth = indoors[indoors['Floor'] == '2']
fig = px.scatter_mapbox(fifth, 
                        lat='Lat', lon='Long', 
                        mapbox_style="stamen-terrain", zoom=16.0,
                        color = 'Description',
                        size='4G upload rate',
                        opacity = 0.7,
                        hover_name='Description', 
                        hover_data=['Location ID','4G download rate', '4G upload rate'],
                        title = '4G Upload Rate - indoors, Second Floors',
 )
fig.update_layout(mapbox_style = 'carto-positron')
fig.show()
# Out:
# <div>                            <div id="75cb2fc0-72d0-4bb1-9cda-6102299c597a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("75cb2fc0-72d0-4bb1-9cda-6102299c597a")) {                    Plotly.newPlot(                        "75cb2fc0-72d0-4bb1-9cda-6102299c597a",                        [{"customdata":[["Rice Hall",77.7,14.3]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Rice Hall West<br>4G upload rate=%{customdata[2]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G download rate=%{customdata[1]}<extra></extra>","hovertext":["Rice Hall West"],"lat":[38.031395],"legendgroup":"Rice Hall West","lon":[-78.510704],"marker":{"color":"#636efa","opacity":0.7,"size":[14.3],"sizemode":"area","sizeref":0.077},"mode":"markers","name":"Rice Hall West","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["Rice Hall",76.6,30.8]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Rice Hall Central<br>4G upload rate=%{customdata[2]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G download rate=%{customdata[1]}<extra></extra>","hovertext":["Rice Hall Central"],"lat":[38.031738],"legendgroup":"Rice Hall Central","lon":[-78.51107],"marker":{"color":"#EF553B","opacity":0.7,"size":[30.8],"sizemode":"area","sizeref":0.077},"mode":"markers","name":"Rice Hall Central","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["Rice Hall",65.3,23.5]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Rice Hall East<br>4G upload rate=%{customdata[2]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G download rate=%{customdata[1]}<extra></extra>","hovertext":["Rice Hall East"],"lat":[38.03175],"legendgroup":"Rice Hall East","lon":[-78.511063],"marker":{"color":"#00cc96","opacity":0.7,"size":[23.5],"sizemode":"area","sizeref":0.077},"mode":"markers","name":"Rice Hall East","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["Olsson Hall",1.8,4.6]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Olsson Hall West<br>4G upload rate=%{customdata[2]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G download rate=%{customdata[1]}<extra></extra>","hovertext":["Olsson Hall West"],"lat":[38.031818],"legendgroup":"Olsson Hall West","lon":[-78.510201],"marker":{"color":"#ab63fa","opacity":0.7,"size":[4.6],"sizemode":"area","sizeref":0.077},"mode":"markers","name":"Olsson Hall West","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["Olsson Hall",0.7,4.7]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Olsson Hall North<br>4G upload rate=%{customdata[2]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G download rate=%{customdata[1]}<extra></extra>","hovertext":["Olsson Hall North"],"lat":[38.032074],"legendgroup":"Olsson Hall North","lon":[-78.510175],"marker":{"color":"#FFA15A","opacity":0.7,"size":[4.7],"sizemode":"area","sizeref":0.077},"mode":"markers","name":"Olsson Hall North","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["Olsson Hall",2.9,4.7]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Olsson Hall East<br>4G upload rate=%{customdata[2]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G download rate=%{customdata[1]}<extra></extra>","hovertext":["Olsson Hall East"],"lat":[38.03199],"legendgroup":"Olsson Hall East","lon":[-78.510818],"marker":{"color":"#19d3f3","opacity":0.7,"size":[4.7],"sizemode":"area","sizeref":0.077},"mode":"markers","name":"Olsson Hall East","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["Wilsdorf Hall",1.0,4.7]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Wilsdorf North<br>4G uplo ...

# %%
fifth = indoors[indoors['Floor'] == '3']
fig = px.scatter_mapbox(fifth, 
                        lat='Lat', lon='Long', 
                        mapbox_style="stamen-terrain", zoom=16.0,
                        color = 'Description',
                        size='4G upload rate',
                        opacity = 0.7,
                        hover_name='Description', 
                        hover_data=['Location ID','4G download rate', '4G upload rate'],
                        title = '4G Upload Rate - indoors, Third Floors',
 )
fig.update_layout(mapbox_style = 'carto-positron')
fig.show()
# Out:
# <div>                            <div id="9d0e9c7c-0d23-4d73-ac78-ba183fa516ae" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9d0e9c7c-0d23-4d73-ac78-ba183fa516ae")) {                    Plotly.newPlot(                        "9d0e9c7c-0d23-4d73-ac78-ba183fa516ae",                        [{"customdata":[["Rice Hall",52.2,6.9]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Rice Hall West<br>4G upload rate=%{customdata[2]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G download rate=%{customdata[1]}<extra></extra>","hovertext":["Rice Hall West"],"lat":[38.031395],"legendgroup":"Rice Hall West","lon":[-78.510704],"marker":{"color":"#636efa","opacity":0.7,"size":[6.9],"sizemode":"area","sizeref":0.0665},"mode":"markers","name":"Rice Hall West","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["Rice Hall",58.9,11.7]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Rice Hall Central<br>4G upload rate=%{customdata[2]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G download rate=%{customdata[1]}<extra></extra>","hovertext":["Rice Hall Central"],"lat":[38.031738],"legendgroup":"Rice Hall Central","lon":[-78.51107],"marker":{"color":"#EF553B","opacity":0.7,"size":[11.7],"sizemode":"area","sizeref":0.0665},"mode":"markers","name":"Rice Hall Central","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["Rice Hall",80.3,26.6]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Rice Hall East<br>4G upload rate=%{customdata[2]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G download rate=%{customdata[1]}<extra></extra>","hovertext":["Rice Hall East"],"lat":[38.03175],"legendgroup":"Rice Hall East","lon":[-78.511063],"marker":{"color":"#00cc96","opacity":0.7,"size":[26.6],"sizemode":"area","sizeref":0.0665},"mode":"markers","name":"Rice Hall East","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["Wilsdorf Hall",0.5,4.6]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Wilsdorf North<br>4G upload rate=%{customdata[2]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G download rate=%{customdata[1]}<extra></extra>","hovertext":["Wilsdorf North"],"lat":[38.03392],"legendgroup":"Wilsdorf North","lon":[-78.511032],"marker":{"color":"#ab63fa","opacity":0.7,"size":[4.6],"sizemode":"area","sizeref":0.0665},"mode":"markers","name":"Wilsdorf North","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["Wilsdorf Hall",1.7,4.7]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Wilsdorf South<br>4G upload rate=%{customdata[2]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G download rate=%{customdata[1]}<extra></extra>","hovertext":["Wilsdorf South"],"lat":[38.033081],"legendgroup":"Wilsdorf South","lon":[-78.511452],"marker":{"color":"#FFA15A","opacity":0.7,"size":[4.7],"sizemode":"area","sizeref":0.0665},"mode":"markers","name":"Wilsdorf South","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["Jesser Hall",1.9,4.6]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Jesser Hall<br>4G upload rate=%{customdata[2]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G download rate=%{customdata[1]}<extra></extra>","hovertext":["Jesser Hall"],"lat":[38.033295],"legendgroup":"Jesser Hall","lon":[-78.510803],"marker":{"color":"#19d3f3","opacity":0.7,"size":[4.6],"sizemode":"area","sizeref":0.0665},"mode":"markers","name":"Jesser Hall","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["Thornton Hall",2.1,4.7],["Thornton Hall",4.3,4.7]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=E-Wing<br>4G upload rate=%{cust ...

# %%
fifth = indoors[indoors['Floor'] == '4']
fig = px.scatter_mapbox(fifth, 
                        lat='Lat', lon='Long', 
                        mapbox_style="stamen-terrain", zoom=18.0,
                        color = 'Description',
                        size='4G upload rate',
                        opacity = 1,
                        hover_name='Description', 
                        hover_data=['Location ID','4G download rate', '4G upload rate'],
                        title = '4G Upload Rate - indoors, Fourth Floors',
 )
fig.update_layout(mapbox_style = 'carto-positron')
fig.show()
# Out:
# <div>                            <div id="dc5e1f1d-1e72-4b02-9f7e-0136046bc944" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dc5e1f1d-1e72-4b02-9f7e-0136046bc944")) {                    Plotly.newPlot(                        "dc5e1f1d-1e72-4b02-9f7e-0136046bc944",                        [{"customdata":[["Rice Hall",69.3,19.6]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Rice Hall West<br>4G upload rate=%{customdata[2]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G download rate=%{customdata[1]}<extra></extra>","hovertext":["Rice Hall West"],"lat":[38.031395],"legendgroup":"Rice Hall West","lon":[-78.510704],"marker":{"color":"#636efa","opacity":1,"size":[19.6],"sizemode":"area","sizeref":0.049},"mode":"markers","name":"Rice Hall West","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["Rice Hall",55.3,19.4]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Rice Hall Central<br>4G upload rate=%{customdata[2]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G download rate=%{customdata[1]}<extra></extra>","hovertext":["Rice Hall Central"],"lat":[38.031738],"legendgroup":"Rice Hall Central","lon":[-78.51107],"marker":{"color":"#EF553B","opacity":1,"size":[19.4],"sizemode":"area","sizeref":0.049},"mode":"markers","name":"Rice Hall Central","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["Rice Hall",41.6,15.7]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Rice Hall East<br>4G upload rate=%{customdata[2]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G download rate=%{customdata[1]}<extra></extra>","hovertext":["Rice Hall East"],"lat":[38.03175],"legendgroup":"Rice Hall East","lon":[-78.511063],"marker":{"color":"#00cc96","opacity":1,"size":[15.7],"sizemode":"area","sizeref":0.049},"mode":"markers","name":"Rice Hall East","showlegend":true,"subplot":"mapbox","type":"scattermapbox"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"] ...

# %%
fifth = indoors[indoors['Floor'] == '5']
fig = px.scatter_mapbox(fifth, 
                        lat='Lat', lon='Long', 
                        mapbox_style="stamen-terrain", zoom=18.0,
                        color = 'Description',
                        size='4G upload rate',
                        opacity = 1,
                        hover_name='Description', 
                        hover_data=['Location ID','4G download rate', '4G upload rate'],
                        title = '4G Download Rate - indoors, Fifth Floors',
 )
fig.update_layout(mapbox_style = 'carto-positron')
fig.show()
# Out:
# <div>                            <div id="48f6ed07-9877-470c-8476-b44a34c36461" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("48f6ed07-9877-470c-8476-b44a34c36461")) {                    Plotly.newPlot(                        "48f6ed07-9877-470c-8476-b44a34c36461",                        [{"customdata":[["Rice Hall",73.4,33.5]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Rice Hall West<br>4G upload rate=%{customdata[2]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G download rate=%{customdata[1]}<extra></extra>","hovertext":["Rice Hall West"],"lat":[38.031395],"legendgroup":"Rice Hall West","lon":[-78.510704],"marker":{"color":"#636efa","opacity":1,"size":[33.5],"sizemode":"area","sizeref":0.08375},"mode":"markers","name":"Rice Hall West","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["Rice Hall",79.5,22.8]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Rice Hall Central<br>4G upload rate=%{customdata[2]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G download rate=%{customdata[1]}<extra></extra>","hovertext":["Rice Hall Central"],"lat":[38.031738],"legendgroup":"Rice Hall Central","lon":[-78.51107],"marker":{"color":"#EF553B","opacity":1,"size":[22.8],"sizemode":"area","sizeref":0.08375},"mode":"markers","name":"Rice Hall Central","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["Rice Hall",56.6,20.0]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Rice Hall East<br>4G upload rate=%{customdata[2]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G download rate=%{customdata[1]}<extra></extra>","hovertext":["Rice Hall East"],"lat":[38.03175],"legendgroup":"Rice Hall East","lon":[-78.511063],"marker":{"color":"#00cc96","opacity":1,"size":[20.0],"sizemode":"area","sizeref":0.08375},"mode":"markers","name":"Rice Hall East","showlegend":true,"subplot":"mapbox","type":"scattermapbox"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d ...

# %% [markdown]
# ### Outdoor Area

# %%
fig = px.histogram(outdoors, '4G download rate', 
                   color = 'Description', 
                   title='Histogram of 4G download rate, by floor',
                   hover_data = ['Description', '4G RSSI signal']
                  )
fig.update_traces(xbins=dict( # bins used for histogram
        start=0.0,
        size=2
    ))
# Out:
# <div>                            <div id="4fc003ff-4949-4198-b7fb-e068dbd6a5f3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4fc003ff-4949-4198-b7fb-e068dbd6a5f3")) {                    Plotly.newPlot(                        "4fc003ff-4949-4198-b7fb-e068dbd6a5f3",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Description=McCormick Road<br>4G download rate=%{x}<br>count=%{y}<extra></extra>","legendgroup":"McCormick Road","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"McCormick Road","offsetgroup":"McCormick Road","orientation":"v","showlegend":true,"x":[2.5],"xaxis":"x","yaxis":"y","type":"histogram","xbins":{"size":2,"start":0.0}},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Description=Darden Courtyard<br>4G download rate=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Darden Courtyard","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Darden Courtyard","offsetgroup":"Darden Courtyard","orientation":"v","showlegend":true,"x":[4.1],"xaxis":"x","yaxis":"y","type":"histogram","xbins":{"size":2,"start":0.0}},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Description=Thornton Courtyard<br>4G download rate=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Thornton Courtyard","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Thornton Courtyard","offsetgroup":"Thornton Courtyard","orientation":"v","showlegend":true,"x":[0.9],"xaxis":"x","yaxis":"y","type":"histogram","xbins":{"size":2,"start":0.0}},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Description=Between Small and Mech<br>4G download rate=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Between Small and Mech","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Between Small and Mech","offsetgroup":"Between Small and Mech","orientation":"v","showlegend":true,"x":[19.1],"xaxis":"x","yaxis":"y","type":"histogram","xbins":{"size":2,"start":0.0}},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Description=Engineer's Way<br>4G download rate=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Engineer's Way","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Engineer's Way","offsetgroup":"Engineer's Way","orientation":"v","showlegend":true,"x":[10.8],"xaxis":"x","yaxis":"y","type":"histogram","xbins":{"size":2,"start":0.0}},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Description=Behind Olsson<br>4G download rate=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Behind Olsson","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Behind Olsson","offsetgroup":"Behind Olsson","orientation":"v","showlegend":true,"x":[6.0],"xaxis":"x","yaxis":"y","type":"histogram","xbins":{"size":2,"start":0.0}},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Description=Front of Thornton<br>4G download rate=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Front of Thornton","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Front of Thornton","offsetgroup":"Front of Thornton","orientation":"v","showlegend":true,"x":[1.9],"xaxis":"x","yaxis":"y","type":"histogram","xbins":{"size":2,"start":0.0}},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Description=Engineer's Way North<br>4G download rate=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Engineer's Way North","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Engineer's Way North","offsetgroup":"Engineer's Way North","orientation":"v","showlegend":true,"x":[1.3],"xaxis":"x","yaxis":"y","type":"histogram","xbins":{"size":2,"start":0.0}},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Description=Behind Mech<br>4G download rate=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Behind Mech","marker":{"color":"#FF97FF","pa ...

# %%
fig = px.histogram(outdoors, '4G upload rate', 
                   color = 'Description', 
                   title='Histogram of 4G upload rate, by floor',
                   hover_data = ['Description', '4G download rate']
                  )
fig.update_traces(xbins=dict( # bins used for histogram
        start=0.0,
        size=2
    ))
# Out:
# <div>                            <div id="a4e24f65-ece2-4a36-a5ff-35ee18e7bdef" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a4e24f65-ece2-4a36-a5ff-35ee18e7bdef")) {                    Plotly.newPlot(                        "a4e24f65-ece2-4a36-a5ff-35ee18e7bdef",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Description=McCormick Road<br>4G upload rate=%{x}<br>count=%{y}<extra></extra>","legendgroup":"McCormick Road","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"McCormick Road","offsetgroup":"McCormick Road","orientation":"v","showlegend":true,"x":[4.6],"xaxis":"x","yaxis":"y","type":"histogram","xbins":{"size":2,"start":0.0}},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Description=Darden Courtyard<br>4G upload rate=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Darden Courtyard","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Darden Courtyard","offsetgroup":"Darden Courtyard","orientation":"v","showlegend":true,"x":[4.6],"xaxis":"x","yaxis":"y","type":"histogram","xbins":{"size":2,"start":0.0}},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Description=Thornton Courtyard<br>4G upload rate=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Thornton Courtyard","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Thornton Courtyard","offsetgroup":"Thornton Courtyard","orientation":"v","showlegend":true,"x":[4.7],"xaxis":"x","yaxis":"y","type":"histogram","xbins":{"size":2,"start":0.0}},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Description=Between Small and Mech<br>4G upload rate=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Between Small and Mech","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Between Small and Mech","offsetgroup":"Between Small and Mech","orientation":"v","showlegend":true,"x":[4.7],"xaxis":"x","yaxis":"y","type":"histogram","xbins":{"size":2,"start":0.0}},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Description=Engineer's Way<br>4G upload rate=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Engineer's Way","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Engineer's Way","offsetgroup":"Engineer's Way","orientation":"v","showlegend":true,"x":[4.7],"xaxis":"x","yaxis":"y","type":"histogram","xbins":{"size":2,"start":0.0}},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Description=Behind Olsson<br>4G upload rate=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Behind Olsson","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Behind Olsson","offsetgroup":"Behind Olsson","orientation":"v","showlegend":true,"x":[4.6],"xaxis":"x","yaxis":"y","type":"histogram","xbins":{"size":2,"start":0.0}},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Description=Front of Thornton<br>4G upload rate=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Front of Thornton","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Front of Thornton","offsetgroup":"Front of Thornton","orientation":"v","showlegend":true,"x":[4.7],"xaxis":"x","yaxis":"y","type":"histogram","xbins":{"size":2,"start":0.0}},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Description=Engineer's Way North<br>4G upload rate=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Engineer's Way North","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Engineer's Way North","offsetgroup":"Engineer's Way North","orientation":"v","showlegend":true,"x":[4.7],"xaxis":"x","yaxis":"y","type":"histogram","xbins":{"size":2,"start":0.0}},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Description=Behind Mech<br>4G upload rate=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Behind Mech","marker":{"color":"#FF97FF","pattern":{"shape":""}} ...

# %%
fig = px.histogram(outdoors, '4G RSSI signal', 
                   color = 'Description', 
                   title='Histogram of 4G RSSI signal, by floor',
                   hover_data = ['Description', '4G download rate', '4G upload rate']
                  )
fig.update_traces(xbins=dict( # bins used for histogram
        size=2
    ))
# Out:
# <div>                            <div id="a70c0306-6e53-4fd3-8c0c-124ea7bbf942" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a70c0306-6e53-4fd3-8c0c-124ea7bbf942")) {                    Plotly.newPlot(                        "a70c0306-6e53-4fd3-8c0c-124ea7bbf942",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Description=McCormick Road<br>4G RSSI signal=%{x}<br>count=%{y}<extra></extra>","legendgroup":"McCormick Road","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"McCormick Road","offsetgroup":"McCormick Road","orientation":"v","showlegend":true,"x":[-80],"xaxis":"x","yaxis":"y","type":"histogram","xbins":{"size":2}},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Description=Darden Courtyard<br>4G RSSI signal=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Darden Courtyard","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Darden Courtyard","offsetgroup":"Darden Courtyard","orientation":"v","showlegend":true,"x":[-75],"xaxis":"x","yaxis":"y","type":"histogram","xbins":{"size":2}},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Description=Thornton Courtyard<br>4G RSSI signal=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Thornton Courtyard","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Thornton Courtyard","offsetgroup":"Thornton Courtyard","orientation":"v","showlegend":true,"x":[-80],"xaxis":"x","yaxis":"y","type":"histogram","xbins":{"size":2}},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Description=Between Small and Mech<br>4G RSSI signal=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Between Small and Mech","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Between Small and Mech","offsetgroup":"Between Small and Mech","orientation":"v","showlegend":true,"x":[-68],"xaxis":"x","yaxis":"y","type":"histogram","xbins":{"size":2}},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Description=Engineer's Way<br>4G RSSI signal=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Engineer's Way","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Engineer's Way","offsetgroup":"Engineer's Way","orientation":"v","showlegend":true,"x":[-72],"xaxis":"x","yaxis":"y","type":"histogram","xbins":{"size":2}},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Description=Behind Olsson<br>4G RSSI signal=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Behind Olsson","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Behind Olsson","offsetgroup":"Behind Olsson","orientation":"v","showlegend":true,"x":[-78],"xaxis":"x","yaxis":"y","type":"histogram","xbins":{"size":2}},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Description=Front of Thornton<br>4G RSSI signal=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Front of Thornton","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Front of Thornton","offsetgroup":"Front of Thornton","orientation":"v","showlegend":true,"x":[-82],"xaxis":"x","yaxis":"y","type":"histogram","xbins":{"size":2}},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Description=Engineer's Way North<br>4G RSSI signal=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Engineer's Way North","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Engineer's Way North","offsetgroup":"Engineer's Way North","orientation":"v","showlegend":true,"x":[-84],"xaxis":"x","yaxis":"y","type":"histogram","xbins":{"size":2}},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Description=Behind Mech<br>4G RSSI signal=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Behind Mech","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Behind Mech","offsetgroup":"Behind Mech","orientation":"v","showlegend":true,"x":[-70], ...

# %%
fig = px.scatter_mapbox(outdoors, 
                        lat='Lat', lon='Long', 
                        mapbox_style="stamen-terrain", zoom=16.0,
                        color = 'Description',
                        size='4G upload rate',
                        opacity = 1,
                        hover_name='Description', 
                        hover_data=['Location ID','4G download rate', '4G upload rate'],
                        title = '4G Upload Rate - Outdoors',
 )
fig.update_layout(mapbox_style = 'carto-positron')
fig.show()
# Out:
# <div>                            <div id="67f7fc2a-c7e8-433f-b5d1-a4929ed8ff50" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("67f7fc2a-c7e8-433f-b5d1-a4929ed8ff50")) {                    Plotly.newPlot(                        "67f7fc2a-c7e8-433f-b5d1-a4929ed8ff50",                        [{"customdata":[["A",2.5,4.6]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=McCormick Road<br>4G upload rate=%{customdata[2]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G download rate=%{customdata[1]}<extra></extra>","hovertext":["McCormick Road"],"lat":[38.033688],"legendgroup":"McCormick Road","lon":[-78.510445],"marker":{"color":"#636efa","opacity":1,"size":[4.6],"sizemode":"area","sizeref":0.021},"mode":"markers","name":"McCormick Road","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["B",4.1,4.6]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Darden Courtyard<br>4G upload rate=%{customdata[2]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G download rate=%{customdata[1]}<extra></extra>","hovertext":["Darden Courtyard"],"lat":[38.033081],"legendgroup":"Darden Courtyard","lon":[-78.509834],"marker":{"color":"#EF553B","opacity":1,"size":[4.6],"sizemode":"area","sizeref":0.021},"mode":"markers","name":"Darden Courtyard","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["C",0.9,4.7]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Thornton Courtyard<br>4G upload rate=%{customdata[2]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G download rate=%{customdata[1]}<extra></extra>","hovertext":["Thornton Courtyard"],"lat":[38.032673],"legendgroup":"Thornton Courtyard","lon":[-78.510193],"marker":{"color":"#00cc96","opacity":1,"size":[4.7],"sizemode":"area","sizeref":0.021},"mode":"markers","name":"Thornton Courtyard","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["D",19.1,4.7]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Between Small and Mech<br>4G upload rate=%{customdata[2]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G download rate=%{customdata[1]}<extra></extra>","hovertext":["Between Small and Mech"],"lat":[38.03207],"legendgroup":"Between Small and Mech","lon":[-78.51104],"marker":{"color":"#ab63fa","opacity":1,"size":[4.7],"sizemode":"area","sizeref":0.021},"mode":"markers","name":"Between Small and Mech","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["E",10.8,4.7]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Engineer's Way<br>4G upload rate=%{customdata[2]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G download rate=%{customdata[1]}<extra></extra>","hovertext":["Engineer's Way"],"lat":[38.03244],"legendgroup":"Engineer's Way","lon":[-78.510757],"marker":{"color":"#FFA15A","opacity":1,"size":[4.7],"sizemode":"area","sizeref":0.021},"mode":"markers","name":"Engineer's Way","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["F",6.0,4.6]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Behind Olsson<br>4G upload rate=%{customdata[2]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G download rate=%{customdata[1]}<extra></extra>","hovertext":["Behind Olsson"],"lat":[38.031811],"legendgroup":"Behind Olsson","lon":[-78.510399],"marker":{"color":"#19d3f3","opacity":1,"size":[4.6],"sizemode":"area","sizeref":0.021},"mode":"markers","name":"Behind Olsson","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["G",1.9,4.7]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Front of Thornton<br>4G upload rate=%{customdata[2]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=% ...

# %%
fig = px.scatter_mapbox(outdoors, 
                        lat='Lat', lon='Long', 
                        mapbox_style="stamen-terrain", zoom=16.0,
                        color = 'Description',
                        size='4G download rate',
                        opacity = 1,
                        hover_name='Description', 
                        hover_data=['Location ID','4G download rate', '4G upload rate'],
                        title = '4G Download Rate - Outdoors',
 )
fig.update_layout(mapbox_style = 'carto-positron')
fig.show()
# Out:
# <div>                            <div id="b440a0e1-f419-4ea1-984d-1b35b1058315" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b440a0e1-f419-4ea1-984d-1b35b1058315")) {                    Plotly.newPlot(                        "b440a0e1-f419-4ea1-984d-1b35b1058315",                        [{"customdata":[["A",2.5,4.6]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=McCormick Road<br>4G download rate=%{customdata[1]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G upload rate=%{customdata[2]}<extra></extra>","hovertext":["McCormick Road"],"lat":[38.033688],"legendgroup":"McCormick Road","lon":[-78.510445],"marker":{"color":"#636efa","opacity":1,"size":[2.5],"sizemode":"area","sizeref":0.08474999999999999},"mode":"markers","name":"McCormick Road","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["B",4.1,4.6]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Darden Courtyard<br>4G download rate=%{customdata[1]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G upload rate=%{customdata[2]}<extra></extra>","hovertext":["Darden Courtyard"],"lat":[38.033081],"legendgroup":"Darden Courtyard","lon":[-78.509834],"marker":{"color":"#EF553B","opacity":1,"size":[4.1],"sizemode":"area","sizeref":0.08474999999999999},"mode":"markers","name":"Darden Courtyard","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["C",0.9,4.7]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Thornton Courtyard<br>4G download rate=%{customdata[1]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G upload rate=%{customdata[2]}<extra></extra>","hovertext":["Thornton Courtyard"],"lat":[38.032673],"legendgroup":"Thornton Courtyard","lon":[-78.510193],"marker":{"color":"#00cc96","opacity":1,"size":[0.9],"sizemode":"area","sizeref":0.08474999999999999},"mode":"markers","name":"Thornton Courtyard","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["D",19.1,4.7]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Between Small and Mech<br>4G download rate=%{customdata[1]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G upload rate=%{customdata[2]}<extra></extra>","hovertext":["Between Small and Mech"],"lat":[38.03207],"legendgroup":"Between Small and Mech","lon":[-78.51104],"marker":{"color":"#ab63fa","opacity":1,"size":[19.1],"sizemode":"area","sizeref":0.08474999999999999},"mode":"markers","name":"Between Small and Mech","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["E",10.8,4.7]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Engineer's Way<br>4G download rate=%{customdata[1]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G upload rate=%{customdata[2]}<extra></extra>","hovertext":["Engineer's Way"],"lat":[38.03244],"legendgroup":"Engineer's Way","lon":[-78.510757],"marker":{"color":"#FFA15A","opacity":1,"size":[10.8],"sizemode":"area","sizeref":0.08474999999999999},"mode":"markers","name":"Engineer's Way","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["F",6.0,4.6]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Behind Olsson<br>4G download rate=%{customdata[1]}<br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G upload rate=%{customdata[2]}<extra></extra>","hovertext":["Behind Olsson"],"lat":[38.031811],"legendgroup":"Behind Olsson","lon":[-78.510399],"marker":{"color":"#19d3f3","opacity":1,"size":[6.0],"sizemode":"area","sizeref":0.08474999999999999},"mode":"markers","name":"Behind Olsson","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["G",1.9,4.7]],"hovertemplate":"<b>%{hovertext}</b><br><br>Description=Front of Tho ...

# %%
fig = px.scatter_mapbox(outdoors, 
                        lat='Lat', lon='Long', 
                        mapbox_style="stamen-terrain", zoom=16.0,
                        color='4G RSSI signal',
                        opacity = 1,
                        hover_name='Description', 
                        hover_data=['Location ID','4G download rate', '4G upload rate'],
                        title = '4G RSSI Signal - Outdoors',
 )
fig.update_layout(mapbox_style = 'carto-positron')
fig.show()
# Out:
# <div>                            <div id="86deb8a6-42fe-4d0e-ab5f-1776686161c3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("86deb8a6-42fe-4d0e-ab5f-1776686161c3")) {                    Plotly.newPlot(                        "86deb8a6-42fe-4d0e-ab5f-1776686161c3",                        [{"customdata":[["A",2.5,4.6],["B",4.1,4.6],["C",0.9,4.7],["D",19.1,4.7],["E",10.8,4.7],["F",6.0,4.6],["G",1.9,4.7],["H",1.3,4.7],["I",15.7,7.0],["J",7.7,4.7],["K",7.7,7.0],["L",33.9,6.5],["M",0.8,4.7],["N",7.4,5.6],["O",12.0,4.7],["P",5.4,8.4],["Q",9.7,4.7],["R",3.1,8.4],["S",4.3,7.0],["T",2.8,7.0],["U",13.5,4.7],["V",11.0,4.6]],"hovertemplate":"<b>%{hovertext}</b><br><br>Lat=%{lat}<br>Long=%{lon}<br>Location ID=%{customdata[0]}<br>4G download rate=%{customdata[1]}<br>4G upload rate=%{customdata[2]}<br>4G RSSI signal=%{marker.color}<extra></extra>","hovertext":["McCormick Road","Darden Courtyard","Thornton Courtyard","Between Small and Mech","Engineer's Way","Behind Olsson","Front of Thornton","Engineer's Way North","Behind Mech","Behind Small Hall","E3 Parking","Behind Wilsdorf North","Behind Wilsdorf South","Behind Chemistry North","Behind Chemistry South","Near AFC","Behind Thornton C-Wing","Near Scott Stadium","Stadium Parking","Bonnycastle","Physics","Near Dorms"],"lat":[38.033688,38.033081,38.032673,38.03207,38.03244,38.031811,38.033649,38.03331,38.032776,38.032177,38.031799,38.033768,38.033058,38.034546,38.034149,38.032673,38.032211,38.032604,38.032001,38.034382,38.033646,38.034447],"legendgroup":"","lon":[-78.510445,-78.509834,-78.510193,-78.51104,-78.510757,-78.510399,-78.509476,-78.510475,-78.511375,-78.511482,-78.511238,-78.511208,-78.51152,-78.511772,-78.511902,-78.512604,-78.510231,-78.512543,-78.513481,-78.511139,-78.509956,-78.511772],"marker":{"color":[-80,-75,-80,-68,-72,-78,-82,-84,-70,-76,-76,-60,-89,-77,-73,-79,-74,-81,-80,-81,-72,-73],"coloraxis":"coloraxis","opacity":1},"mode":"markers","name":"","showlegend":false,"subplot":"mapbox","type":"scattermapbox"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewi ...

# %% [markdown]
# ### Indoor Areas Stats

# %%
print("Stats for INDOORS download rate")
print("mean", indoors['4G download rate'].mean())
print("standard deviation", indoors['4G download rate'].std())
print("range", range_down)
print("------------")
print("Stats for INDOORS upload rate")
print("mean", indoors['4G upload rate'].mean())
print("standard deviation", indoors['4G upload rate'].std())
print("range", range_up)
print("------------")
print("Stats for INDOORS RSSI Signal")
print("mean", indoors['4G download rate'].mean())
print("standard deviation", indoors['4G RSSI signal'].std())
print("range*", range_rssi)

print("*note: the -200 in rssi range reprents no signal, if we use -infinity it would skew the color map too much")
# Out:
# Stats for INDOORS download rate
# mean 16.468354430379755
# standard deviation 27.390081230647827
# range [0.0, 80.3]
# ------------
# Stats for INDOORS upload rate
# mean 7.994936708860766
# standard deviation 7.982045537171615
# range [0.0, 33.5]
# ------------
# Stats for INDOORS RSSI Signal
# mean 16.468354430379755
# standard deviation 25.651365166229834
# range* [-200, -71]
# *note: the -200 in rssi range reprents no signal, if we use -infinity it would skew the color map too much

# %%
print("Stats for OUTDOORS download rate")
print("mean", outdoors['4G download rate'].mean())
print("standard deviation", outdoors['4G download rate'].std())
range_out_max = outdoors['4G download rate'].max()
range_out_min = outdoors['4G download rate'].min()
range_out_down = [range_out_min, range_out_max]
print("range", range_out_down)

print("------------")

print("Stats for indoors upload rate")
print("mean", outdoors['4G upload rate'].mean())
range_out_max = outdoors['4G upload rate'].max()
range_out_min = outdoors['4G upload rate'].min()
range_out_up = [range_out_min, range_out_max]
print("standard deviation", outdoors['4G upload rate'].std())
print("range", range_out_up)
print("------------")
print("Stats for indoors RSSI Signal")
print("mean", outdoors['4G download rate'].mean())
print("standard deviation", outdoors['4G RSSI signal'].std())
print("range*", range_rssi)

print("*note: the -200 in rssi range reprents no signal, if we use -infinity it would skew the color map too much")
# Out:
# Stats for OUTDOORS download rate
# mean 8.254545454545456
# standard deviation 7.633617832464578
# range [0.8, 33.9]
# ------------
# Stats for indoors upload rate
# mean 5.5590909090909095
# standard deviation 1.3164378671280532
# range [4.6, 8.4]
# ------------
# Stats for indoors RSSI Signal
# mean 8.254545454545456
# standard deviation 6.129906816237713
# range* [-200, -71]
# *note: the -200 in rssi range reprents no signal, if we use -infinity it would skew the color map too much

# %% [markdown]
# ### Find the low download, upload rate areas:

# %%
mean_indoors_down = indoors['4G download rate'].mean()
fig = px.bar(indoors.sort_values(by = '4G download rate', ascending = True), x = 'Description', y = '4G download rate', 
       color = 'Floor', color_discrete_sequence= px.colors.qualitative.Vivid, barmode='group',
       title = 'Indoors Download Rate by Location',
       hover_data = ['4G RSSI signal', '4G upload rate'],
       labels= {'Description': "Location"})
fig.add_hline(indoors['4G download rate'].mean(), line_dash = 'dash')
# Out:
# <div>                            <div id="523281ca-6890-4ace-a327-b083eaabda26" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("523281ca-6890-4ace-a327-b083eaabda26")) {                    Plotly.newPlot(                        "523281ca-6890-4ace-a327-b083eaabda26",                        [{"alignmentgroup":"True","customdata":[[-107.0,0.0],[-99.0,0.0],[-102.0,0.0],[-101.0,4.7],[-103.0,4.6],[-108.0,4.7],[-84.0,4.7],[-122.0,4.7],[-101.0,7.0],[-117.0,4.7],[-96.0,4.6],[-110.0,4.7],[-80.0,7.4],[-94.0,28.0],[-93.0,23.0]],"hovertemplate":"Floor=0<br>Location=%{x}<br>4G download rate=%{y}<br>4G RSSI signal=%{customdata[0]}<br>4G upload rate=%{customdata[1]}<extra></extra>","legendgroup":"0","marker":{"color":"rgb(229, 134, 6)","pattern":{"shape":""}},"name":"0","offsetgroup":"0","orientation":"v","showlegend":true,"textposition":"auto","x":["A-Wing Central","Mech Central","C-Wing","Mech North","A-Wing East","Olsson Hall East","D-Wing","Olsson Hall North","Small Hall","Olsson Hall West","Mech South","A-Wing West","Rice Hall West","Rice Hall Central","Rice Hall East"],"xaxis":"x","y":[0.0,0.0,0.0,0.1,0.4,0.4,0.7,1.3,1.5,1.7,1.7,2.5,45.6,63.3,77.5],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[-200.0,0.0],[-200.0,4.7]],"hovertemplate":"Floor=A<br>Location=%{x}<br>4G download rate=%{y}<br>4G RSSI signal=%{customdata[0]}<br>4G upload rate=%{customdata[1]}<extra></extra>","legendgroup":"A","marker":{"color":"rgb(93, 105, 177)","pattern":{"shape":""}},"name":"A","offsetgroup":"A","orientation":"v","showlegend":true,"textposition":"auto","x":["Wilsdorf North","Wilsdorf South"],"xaxis":"x","y":[0.0,5.4],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[-111.0,12.1],[-97.0,4.7],[-98.0,4.7],[-87.0,2.8],[-72.0,14.0],[-93.0,0.5],[-115.0,4.6],[-90.0,4.4],[-93.0,4.7],[-99.0,4.7],[-113.0,4.6],[-94.0,4.6],[-88.0,4.7],[-102.0,4.6],[-89.0,4.7],[-92.0,4.7],[-109.0,2.8],[-90.0,3.3],[-93.0,5.8],[-110.0,7.0],[-92.0,12.1],[-85.0,29.4],[-95.0,22.1]],"hovertemplate":"Floor=1<br>Location=%{x}<br>4G download rate=%{y}<br>4G RSSI signal=%{customdata[0]}<br>4G upload rate=%{customdata[1]}<extra></extra>","legendgroup":"1","marker":{"color":"rgb(82, 188, 163)","pattern":{"shape":""}},"name":"1","offsetgroup":"1","orientation":"v","showlegend":true,"textposition":"auto","x":["E-Wing","B-Wing","A-Wing Central","C-Wing","D-Wing","C-Wing","Olsson Hall North","B-Wing","A-Wing East","E-Wing","Olsson Hall West","Wilsdorf North","Mech South","A-Wing West","D-Wing","Wilsdorf South","Olsson Hall East","Mech Central","Mech North","Small Hall","Rice Hall West","Rice Hall East","Rice Hall Central"],"xaxis":"x","y":[0.0,0.1,0.3,0.3,0.5,0.7,0.9,1.0,1.1,1.3,1.4,1.4,1.7,2.0,2.2,2.9,3.5,4.8,6.4,16.1,63.0,63.7,76.4],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[-96.0,0.0],[-80.0,0.0],[-78.0,4.7],[-93.0,4.6],[-100.0,4.7],[-100.0,4.6],[-88.0,4.7],[-100.0,4.7],[-89.0,4.7],[-85.0,5.6],[-87.0,5.8],[-96.0,4.6],[-92.0,4.7],[-98.0,4.7],[-91.0,4.7],[-85.0,4.7],[-86.0,4.6],[-82.0,4.7],[-85.0,4.6],[-79.0,7.0],[-102.0,23.5],[-95.0,30.8],[-90.0,14.3]],"hovertemplate":"Floor=2<br>Location=%{x}<br>4G download rate=%{y}<br>4G RSSI signal=%{customdata[0]}<br>4G upload rate=%{customdata[1]}<extra></extra>","legendgroup":"2","marker":{"color":"rgb(153, 201, 69)","pattern":{"shape":""}},"name":"2","offsetgroup":"2","orientation":"v","showlegend":true,"textposition":"auto","x":["E-Wing","C-Wing","D-Wing","Wilsdorf South","Olsson Hall North","D-Wing","A-Wing East","Wilsdorf North","A-Wing West","Jesser Hall","E-Wing","Olsson Hall West","A-Wing Central","Olsson Hall East","B-Wing","C-Wing","Mech North","Mech Central","B-Wing","Mech South","Rice Hall East","Rice Hall Central","Rice Hall West"],"xaxis":"x","y":[0.0,0 ...

# %%
mean_indoors_up = indoors['4G upload rate'].mean()
fig = px.bar(indoors.sort_values(by = '4G upload rate', ascending = True), x = 'Description', y = '4G download rate', 
       barmode='group',
       color = 'Floor', color_discrete_sequence= px.colors.qualitative.Vivid,
       title = 'Indoors Upload Rate by Location',
       hover_data = ['4G RSSI signal', '4G upload rate'],
       labels= {'Description': "Location"})
fig.add_hline(mean_indoors_up, line_dash = 'dash')
# Out:
# <div>                            <div id="4eda7780-aaf8-4f2e-900d-14b4f4f07294" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4eda7780-aaf8-4f2e-900d-14b4f4f07294")) {                    Plotly.newPlot(                        "4eda7780-aaf8-4f2e-900d-14b4f4f07294",                        [{"alignmentgroup":"True","customdata":[[-107.0,0.0],[-102.0,0.0],[-99.0,0.0],[-103.0,4.6],[-96.0,4.6],[-110.0,4.7],[-101.0,4.7],[-84.0,4.7],[-117.0,4.7],[-122.0,4.7],[-108.0,4.7],[-101.0,7.0],[-80.0,7.4],[-93.0,23.0],[-94.0,28.0]],"hovertemplate":"Floor=0<br>Location=%{x}<br>4G download rate=%{y}<br>4G RSSI signal=%{customdata[0]}<br>4G upload rate=%{customdata[1]}<extra></extra>","legendgroup":"0","marker":{"color":"rgb(229, 134, 6)","pattern":{"shape":""}},"name":"0","offsetgroup":"0","orientation":"v","showlegend":true,"textposition":"auto","x":["A-Wing Central","C-Wing","Mech Central","A-Wing East","Mech South","A-Wing West","Mech North","D-Wing","Olsson Hall West","Olsson Hall North","Olsson Hall East","Small Hall","Rice Hall West","Rice Hall East","Rice Hall Central"],"xaxis":"x","y":[0.0,0.0,0.0,0.4,1.7,2.5,0.1,0.7,1.7,1.3,0.4,1.5,45.6,77.5,63.3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[-200.0,0.0],[-200.0,0.0]],"hovertemplate":"Floor=B<br>Location=%{x}<br>4G download rate=%{y}<br>4G RSSI signal=%{customdata[0]}<br>4G upload rate=%{customdata[1]}<extra></extra>","legendgroup":"B","marker":{"color":"rgb(93, 105, 177)","pattern":{"shape":""}},"name":"B","offsetgroup":"B","orientation":"v","showlegend":true,"textposition":"auto","x":["Wilsdorf North","Wilsdorf South"],"xaxis":"x","y":[0.0,0.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[-200.0,0.0],[-200.0,4.7]],"hovertemplate":"Floor=A<br>Location=%{x}<br>4G download rate=%{y}<br>4G RSSI signal=%{customdata[0]}<br>4G upload rate=%{customdata[1]}<extra></extra>","legendgroup":"A","marker":{"color":"rgb(82, 188, 163)","pattern":{"shape":""}},"name":"A","offsetgroup":"A","orientation":"v","showlegend":true,"textposition":"auto","x":["Wilsdorf North","Wilsdorf South"],"xaxis":"x","y":[0.0,5.4],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[-96.0,0.0],[-80.0,0.0],[-96.0,4.6],[-86.0,4.6],[-85.0,4.6],[-93.0,4.6],[-100.0,4.6],[-85.0,4.7],[-92.0,4.7],[-88.0,4.7],[-91.0,4.7],[-89.0,4.7],[-100.0,4.7],[-82.0,4.7],[-100.0,4.7],[-98.0,4.7],[-78.0,4.7],[-85.0,5.6],[-87.0,5.8],[-79.0,7.0],[-90.0,14.3],[-102.0,23.5],[-95.0,30.8]],"hovertemplate":"Floor=2<br>Location=%{x}<br>4G download rate=%{y}<br>4G RSSI signal=%{customdata[0]}<br>4G upload rate=%{customdata[1]}<extra></extra>","legendgroup":"2","marker":{"color":"rgb(153, 201, 69)","pattern":{"shape":""}},"name":"2","offsetgroup":"2","orientation":"v","showlegend":true,"textposition":"auto","x":["E-Wing","C-Wing","Olsson Hall West","Mech North","B-Wing","Wilsdorf South","D-Wing","C-Wing","A-Wing Central","A-Wing East","B-Wing","A-Wing West","Wilsdorf North","Mech Central","Olsson Hall North","Olsson Hall East","D-Wing","Jesser Hall","E-Wing","Mech South","Rice Hall West","Rice Hall East","Rice Hall Central"],"xaxis":"x","y":[0.0,0.0,1.8,5.3,6.2,0.6,0.7,5.1,2.5,0.9,3.8,1.0,1.0,5.4,0.7,2.9,0.4,1.7,1.8,8.2,77.7,65.3,76.6],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[-93.0,0.5],[-87.0,2.8],[-109.0,2.8],[-90.0,3.3],[-90.0,4.4],[-102.0,4.6],[-115.0,4.6],[-113.0,4.6],[-94.0,4.6],[-98.0,4.7],[-93.0,4.7],[-97.0,4.7],[-92.0,4.7],[-88.0,4.7],[-99.0,4.7],[-89.0,4.7],[-93.0,5.8],[-110.0,7.0],[-92.0,12.1],[-111.0,12.1],[-72.0,14.0],[-95.0,22.1],[-85.0,29.4]],"hovertemplate":"Floor=1<br>Location=%{x}<br>4G download rate=%{y}<br>4G RSSI signal=%{customdata[0]}<br>4G upload rate=%{customdata[1]}<extra></extra>","legendgroup":"1","marker":{"color" ...

# %%
mean_indoors_rssi = indoors['4G RSSI signal'].mean()
fig = px.bar(indoors.sort_values(by = '4G RSSI signal', ascending = True), x = 'Description', y = '4G RSSI signal', 
       color = 'Floor', color_discrete_sequence= px.colors.qualitative.Vivid, barmode = 'group',
       title = 'Indoors RSSI Signal by Location',
       hover_data = ['4G RSSI signal', '4G upload rate'],
       labels= {'Description': "Location"})
fig.add_hline(mean_indoors_rssi, line_dash = 'dash')
# Out:
# <div>                            <div id="ea6f887e-bedd-4e44-a49b-23a70058f795" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ea6f887e-bedd-4e44-a49b-23a70058f795")) {                    Plotly.newPlot(                        "ea6f887e-bedd-4e44-a49b-23a70058f795",                        [{"alignmentgroup":"True","customdata":[[0.0],[4.7]],"hovertemplate":"Floor=A<br>Location=%{x}<br>4G RSSI signal=%{y}<br>4G upload rate=%{customdata[0]}<extra></extra>","legendgroup":"A","marker":{"color":"rgb(229, 134, 6)","pattern":{"shape":""}},"name":"A","offsetgroup":"A","orientation":"v","showlegend":true,"textposition":"auto","x":["Wilsdorf North","Wilsdorf South"],"xaxis":"x","y":[-200,-200],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[0.0],[0.0]],"hovertemplate":"Floor=B<br>Location=%{x}<br>4G RSSI signal=%{y}<br>4G upload rate=%{customdata[0]}<extra></extra>","legendgroup":"B","marker":{"color":"rgb(93, 105, 177)","pattern":{"shape":""}},"name":"B","offsetgroup":"B","orientation":"v","showlegend":true,"textposition":"auto","x":["Wilsdorf North","Wilsdorf South"],"xaxis":"x","y":[-200,-200],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[4.7],[4.7],[4.7],[4.7],[0.0],[4.6],[0.0],[7.0],[4.7],[0.0],[4.6],[28.0],[23.0],[4.7],[7.4]],"hovertemplate":"Floor=0<br>Location=%{x}<br>4G RSSI signal=%{y}<br>4G upload rate=%{customdata[0]}<extra></extra>","legendgroup":"0","marker":{"color":"rgb(82, 188, 163)","pattern":{"shape":""}},"name":"0","offsetgroup":"0","orientation":"v","showlegend":true,"textposition":"auto","x":["Olsson Hall North","Olsson Hall West","A-Wing West","Olsson Hall East","A-Wing Central","A-Wing East","C-Wing","Small Hall","Mech North","Mech Central","Mech South","Rice Hall Central","Rice Hall East","D-Wing","Rice Hall West"],"xaxis":"x","y":[-122,-117,-110,-108,-107,-103,-102,-101,-101,-99,-96,-94,-93,-84,-80],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[4.6],[4.6],[12.1],[7.0],[2.8],[4.6],[4.7],[4.7],[4.7],[22.1],[4.6],[5.8],[0.5],[4.7],[12.1],[4.7],[3.3],[4.4],[4.7],[4.7],[2.8],[29.4],[14.0]],"hovertemplate":"Floor=1<br>Location=%{x}<br>4G RSSI signal=%{y}<br>4G upload rate=%{customdata[0]}<extra></extra>","legendgroup":"1","marker":{"color":"rgb(153, 201, 69)","pattern":{"shape":""}},"name":"1","offsetgroup":"1","orientation":"v","showlegend":true,"textposition":"auto","x":["Olsson Hall North","Olsson Hall West","E-Wing","Small Hall","Olsson Hall East","A-Wing West","E-Wing","A-Wing Central","B-Wing","Rice Hall Central","Wilsdorf North","Mech North","C-Wing","A-Wing East","Rice Hall West","Wilsdorf South","Mech Central","B-Wing","D-Wing","Mech South","C-Wing","Rice Hall East","D-Wing"],"xaxis":"x","y":[-115,-113,-111,-110,-109,-102,-99,-98,-97,-95,-94,-93,-93,-93,-92,-92,-90,-90,-89,-88,-87,-85,-72],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[4.6],[4.7],[4.7],[4.7],[26.6],[6.9],[11.7],[4.6]],"hovertemplate":"Floor=3<br>Location=%{x}<br>4G RSSI signal=%{y}<br>4G upload rate=%{customdata[0]}<extra></extra>","legendgroup":"3","marker":{"color":"rgb(204, 97, 176)","pattern":{"shape":""}},"name":"3","offsetgroup":"3","orientation":"v","showlegend":true,"textposition":"auto","x":["Wilsdorf North","Wilsdorf South","E-Wing","E-Wing","Rice Hall East","Rice Hall West","Rice Hall Central","Jesser Hall"],"xaxis":"x","y":[-102,-98,-87,-85,-85,-84,-83,-82],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[23.5],[4.6],[4.7],[4.7],[4.7],[0.0],[4.6],[30.8],[4.6],[4.7],[4.7],[14.3],[4.7],[4.7],[5.8],[4.6],[5.6],[4.7],[4.6],[4.7],[0.0],[7.0],[4.7]],"hovertemplate":"Floor=2<br>Location=%{x}<br>4G RSSI signal=%{y}<br>4G upload rate=%{customdata[0]}<extra></extra>","legendgroup":"2","marker":{"color":"rgb(36,  ...

# %% [markdown]
# ## Outdoors Statistics

# %%
mean_outdoors_down = outdoors['4G download rate'].mean()
fig = px.bar(outdoors.sort_values(by = '4G download rate', ascending = True), x = 'Description', y = '4G download rate', 
       title = 'Outdoors Download Rate by Location',
       hover_data = ['4G RSSI signal', '4G upload rate'],
       labels= {'Description': "Location"})
fig.add_hline(mean_outdoors_down, line_dash = 'dash', annotation_text="outdoors download rate avg")
fig.add_hline(mean_indoors_down, line_dash = 'dash', line_color= 'red',annotation_text="indoors download rate avg")
fig.update_annotations(align='left')
# Out:
# <div>                            <div id="20a5e156-3ae3-44c3-a0b3-1d69b8ab0028" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("20a5e156-3ae3-44c3-a0b3-1d69b8ab0028")) {                    Plotly.newPlot(                        "20a5e156-3ae3-44c3-a0b3-1d69b8ab0028",                        [{"alignmentgroup":"True","customdata":[[-89.0,4.7],[-80.0,4.7],[-84.0,4.7],[-82.0,4.7],[-80.0,4.6],[-81.0,7.0],[-81.0,8.4],[-75.0,4.6],[-80.0,7.0],[-79.0,8.4],[-78.0,4.6],[-77.0,5.6],[-76.0,7.0],[-76.0,4.7],[-74.0,4.7],[-72.0,4.7],[-73.0,4.6],[-73.0,4.7],[-72.0,4.7],[-70.0,7.0],[-68.0,4.7],[-60.0,6.5]],"hovertemplate":"Location=%{x}<br>4G download rate=%{y}<br>4G RSSI signal=%{customdata[0]}<br>4G upload rate=%{customdata[1]}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Behind Wilsdorf South","Thornton Courtyard","Engineer's Way North","Front of Thornton","McCormick Road","Bonnycastle","Near Scott Stadium","Darden Courtyard","Stadium Parking","Near AFC","Behind Olsson","Behind Chemistry North","E3 Parking","Behind Small Hall","Behind Thornton C-Wing","Engineer's Way","Near Dorms","Behind Chemistry South","Physics","Behind Mech","Between Small and Mech","Behind Wilsdorf North"],"xaxis":"x","y":[0.8,0.9,1.3,1.9,2.5,2.8,3.1,4.1,4.3,5.4,6.0,7.4,7.7,7.7,9.7,10.8,11.0,12.0,13.5,15.7,19.1,33.9],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555 ...

# %%
mean_outdoors_up = outdoors['4G upload rate'].mean()
fig = px.bar(outdoors.sort_values(by = '4G upload rate', ascending = True), x = 'Description', y = '4G upload rate', 
       
       title = 'Outdoors Upload Rate by Location',
       hover_data = ['4G download rate', '4G download rate'],
       labels= {'Description': "Location"})
fig.add_hline(mean_indoors_up, line_dash = 'dash', line_color = 'red, annotation_text="indoors upload rate avg")
fig.add_hline(mean_outdoors_up, line_dash = 'dash', annotation_text="outdoors download rate avg")
# Out:
#   File "/var/folders/1l/mmyy9v2n47l_70ty0lkv3zz80000gn/T/ipykernel_48101/3313682613.py", line 7
#     fig.add_hline(mean_indoors_up, line_dash = 'dash', line_color = 'red, annotation_text="indoors upload rate avg")
#                                                                                                                     ^
# SyntaxError: EOL while scanning string literal

# %%
mean_outdoors_rssi = outdoors['4G RSSI signal'].mean()
fig = px.bar(outdoors.sort_values(by = '4G RSSI signal', ascending = True), x = 'Description', y = '4G RSSI signal', 
       
       title = 'Outdoors RSSI Signal by Location',
       hover_data = ['4G download rate', '4G upload rate'],
       labels= {'Description': "Location"})
fig.add_hline(mean_indoors_rssi, line_dash = 'dash',line_color = 'red',  annotation_text="indoors RSSI avg")
fig.add_hline(mean_outdoors_rssi, line_dash = 'dash', annotation_text="outdoors RSSI avg")
# Out:
# <div>                            <div id="f722068f-a9bd-4e3b-9177-c20bac3f9aed" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f722068f-a9bd-4e3b-9177-c20bac3f9aed")) {                    Plotly.newPlot(                        "f722068f-a9bd-4e3b-9177-c20bac3f9aed",                        [{"alignmentgroup":"True","customdata":[[0.8,4.7],[1.3,4.7],[1.9,4.7],[2.8,7.0],[3.1,8.4],[2.5,4.6],[0.9,4.7],[4.3,7.0],[5.4,8.4],[6.0,4.6],[7.4,5.6],[7.7,7.0],[7.7,4.7],[4.1,4.6],[9.7,4.7],[12.0,4.7],[11.0,4.6],[13.5,4.7],[10.8,4.7],[15.7,7.0],[19.1,4.7],[33.9,6.5]],"hovertemplate":"Location=%{x}<br>4G RSSI signal=%{y}<br>4G download rate=%{customdata[0]}<br>4G upload rate=%{customdata[1]}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Behind Wilsdorf South","Engineer's Way North","Front of Thornton","Bonnycastle","Near Scott Stadium","McCormick Road","Thornton Courtyard","Stadium Parking","Near AFC","Behind Olsson","Behind Chemistry North","E3 Parking","Behind Small Hall","Darden Courtyard","Behind Thornton C-Wing","Behind Chemistry South","Near Dorms","Physics","Engineer's Way","Behind Mech","Between Small and Mech","Behind Wilsdorf North"],"xaxis":"x","y":[-89,-84,-82,-81,-81,-80,-80,-80,-79,-78,-77,-76,-76,-75,-74,-73,-73,-72,-72,-70,-68,-60],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666, ...

# %%
indoors[['']]

# %% [markdown]
# ### Conclusion:
# 4G download rates are generally not very good, with a range of [0, 80.3] but a mean of
